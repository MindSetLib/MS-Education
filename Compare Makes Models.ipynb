# %%
import difflib as dl

# %%
import keyword

# %%
import pandas as pd

# %%
f = open(u'C:\\work\\Бизнес проекты\\16. MindSet\\! Проекты\\2018-10 AI - MakesModels compare\\MMs.csv')
data = pd.read_csv(f, sep=';')

# %%
data.head()
# Out:
#   Make Transdekra Model Transdekra MakeModel Transdekra        Ren  \
# 0           Acura              MDX            Acura MDX  Acura MDX
# 1           Acura              RDX            Acura RDX  Acura RDX
# 2           Acura              TLX            Acura TLX   Acura RL
# 3      Alfa Romeo              147       Alfa Romeo 147   Acura TL
# 4      Alfa Romeo              159       Alfa Romeo 159  Acura TLX
#
#            Pkasko
# 0       Acura MDX
# 1       Acura RDX
# 2       Acura TLX
# 3  Alfa Romeo 147
# 4  Alfa Romeo 159

# %%
data['MakeModel Transdekra'][0:10]
# Out:
# 0               Acura MDX
# 1               Acura RDX
# 2               Acura TLX
# 3          Alfa Romeo 147
# 4          Alfa Romeo 159
# 5           Alfa Romeo 4C
# 6        Alfa Romeo Brera
# 7           Alfa Romeo GT
# 8    Alfa Romeo Giulietta
# 9         Alfa Romeo MiTo
# Name: MakeModel Transdekra, dtype: object

# %%
for i in range(0,800):
    print(data['MakeModel Transdekra'][i],"-",dl.get_close_matches(data['MakeModel Transdekra'][i], data['Ren'],1))
# Out:
# Acura MDX - ['Acura MDX']
# Acura RDX - ['Acura RDX']
# Acura TLX - ['Acura TLX']
# Alfa Romeo 147 - ['Alfa Romeo 147']
# Alfa Romeo 159 - ['Alfa Romeo 159']
# Alfa Romeo 4C - ['Alfa Romeo 4c']
# Alfa Romeo Brera - ['Alfa Romeo Brera']
# Alfa Romeo GT - ['Alfa Romeo GT']
# Alfa Romeo Giulietta - ['Alfa Romeo Giulietta']
# Alfa Romeo MiTo - ['Alfa Romeo MiTo']
# Alfa Romeo Spider - ['Alfa Romeo Spider']
# Aston Martin Cygnet - ['Aston Martin V8']
# Aston Martin DB11 - ['Aston Martin Db9']
# Aston Martin DB9 - ['Aston Martin Db9']
# Aston Martin DBS - ['Aston Martin Db9']
# Aston Martin Rapide - ['Aston Martin V8']
# Aston Martin V12 Vantage - ['Aston Martin V12 Vanquish']
# Aston Martin V8 Vantage - ['Aston Martin V8']
# Aston Martin Vanquish - ['Aston Martin V12 Vanquish']
# Aston Martin Virage - ['Aston Martin V8']
# Audi A1 - ['Audi A1']
# Audi A3 - ['Audi A3']
# Audi A4 - ['Audi A4']
# Audi A4 allroad quattro - ['Audi A4 Allroad']
# Audi A5 - ['Audi A5']
# Audi A6 - ['Audi A6']
# ...
