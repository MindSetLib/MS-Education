# %% [markdown]
# # Описание кейса «Прогнозирование оттока клиентов»
#
# Суть бизнес задачи:
# Каждый месяц компания пролонгирует полисы Каско клиентов - физических лиц. Для оптимизации работы со списками на пролонгацию необходимо прогнозировать с какой вероятностью каждый из клиентов пролонгируется и какие факторы на это влияют. В зависимости от этого расставляются приоритеты операторам колл-центра, которые обрабатывают список (осуществляют обзвон клиентов), а также принимаются решения по дополнительной мотивации клиентов к пролонгации.
#
# Описание массива:
# Дана выборка полисов на пролонгацию в формате CSV-файла с набором полей, характеризующих сам полис, клиента (и его историю страхования) и транспортное средство.
# Полис на пролонгацию – это полис, период действия заканчивается и который нужно пролонгировать.
# Прогнозируемая переменная – факт пролонгации полиса «POLICY_IS_RENEWED», где «1» – клиент пролонгировался, «0» - клиент не пролонгировался.
# Массив случайным образом разбит на 2 части: 80% данных – тренировочная выборка, 20% данных – тестовая выборка.

# %%
#Присоединяем библиотеки для работы расчетов - pandas, numpy, matplotlib
#Import libraries to porogram pandas, numpym matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Открываем файл csv содержащий данные программы, импортируем данные в датафрейм pandas
#Open csv file with data, import data to pandas dataframe
url = 'https://github.com/MindSetLib/PythonUsefull/raw/master/BinaryClassificationInsuranceRenewal/InsuranceRenewalDB.csv'
data = pd.read_csv(url, sep=';', encoding='utf-8')

# %%
#Исследуем данные - посмотрим на верхние 5 строк
#Explortory data analysis - have a loot at the data
data.head()
# Out:
#   DATA_TYPE  POLICY_ID  POLICY_BEGIN_MONTH  POLICY_END_MONTH  \
# 0     TRAIN          1                   1                 1
# 1     TRAIN          2                   1                 1
# 2     TRAIN          3                   1                 1
# 3     TRAIN          4                   1                 1
# 4     TRAIN          5                   1                 1
#
#    POLICY_IS_RENEWED  POLICY_SALES_CHANNEL  POLICY_SALES_CHANNEL_GROUP  \
# 0                  1                    39                           1
# 1                  1                    50                           5
# 2                  1                    52                           6
# 3                  1                    50                           5
# 4                  0                    52                           6
#
#      POLICY_BRANCH  POLICY_MIN_AGE  POLICY_MIN_DRIVING_EXPERIENCE  \
# 0           Москва              51                             12
# 1           Москва              35                              7
# 2           Москва              41                              6
# 3           Москва              36                             12
# 4  Санкт-Петербург              42                              5
#
#           ...         POLICY_PRV_CLM_GLT_N CLIENT_HAS_DAGO  CLIENT_HAS_OSAGO  \
# 0         ...                            N               1                 0
# 1         ...                            0               1                 1
# 2         ...                           1L               0                 0
# 3         ...                            0               1                 1
# 4         ...                            N               0                 0
#
#    POLICY_COURT_SIGN  CLAIM_AVG_ACC_ST_PRD POLICY_HAS_COMPLAINTS  \
# 0                  0                     0                     0
# 1                  0                     0                     0
# 2                  0                     0                     0
# 3                  0                     0                     0
# 4                  0                     0                     0
#
#   POLICY_YEARS_RENEWED_N POLICY_DEDUCT_VALUE CLIENT_REGISTRATION_REGION  \
# 0                      0                 0.0                   Тульская
# 1                      4                 0.0                     Москва
# 2                      1             12518.0                 Московская
# 3                      6             15000.0                     Москва
# 4                      0             50000.0              Ленинградская
#
#   POLICY_PRICE_CHANGE
# 0               -1.00
# 1               -0.05
# 2               -0.07
# 3                0.05
# 4                0.17
#
# [5 rows x 30 columns]

# %%
# Посмотрим на размер датафрейма
# Let's have a loot at dataframe shape
data.shape
# Out:
# (95352, 30)

# %%
# Детальнее взглянем на данные и ключевые статистики по ним
# Lets have a look at details and key statistics
data.describe()
# Out:
#           POLICY_ID  POLICY_BEGIN_MONTH  POLICY_END_MONTH  POLICY_IS_RENEWED  \
# count  95352.000000        95352.000000      95352.000000       95352.000000
# mean   48294.907385            6.881660          6.860779           0.506754
# std    27889.234251            3.401097          3.404167           0.499957
# min        1.000000            1.000000          1.000000           0.000000
# 25%    24132.750000            4.000000          4.000000           0.000000
# 50%    48309.500000            7.000000          7.000000           1.000000
# 75%    72444.250000           10.000000         10.000000           1.000000
# max    96605.000000           12.000000         12.000000           1.000000
#
#        POLICY_SALES_CHANNEL  POLICY_SALES_CHANNEL_GROUP  POLICY_MIN_AGE  \
# count          95352.000000                95352.000000    95352.000000
# mean              47.393007                    5.129614       42.604015
# std               13.986007                    1.577412       10.697854
# min                1.000000                    1.000000       18.000000
# 25%               50.000000                    5.000000       34.000000
# 50%               52.000000                    6.000000       41.000000
# 75%               53.000000                    6.000000       50.000000
# max               63.000000                    8.000000       86.000000
#
#        POLICY_MIN_DRIVING_EXPERIENCE  VEHICLE_ENGINE_POWER  VEHICLE_IN_CREDIT  \
# count                   95352.000000          95352.000000       95352.000000
# mean                       35.075122            153.788627           0.321472
# std                       200.723291             53.690138           0.467044
# min                         0.000000              0.000000           0.000000
# 25%                         8.000000            122.000000           0.000000
# 50%                        14.000000            146.000000           0.000000
# 75%                        19.000000            171.000000           1.000000
# max                      2015.000000           2000.000000           1.000000
#
#        VEHICLE_SUM_INSURED  CLIENT_HAS_DAGO  CLIENT_HAS_OSAGO  \
# count         9.535200e+04     95352.000000      95352.000000
# mean          9.760132e+05         0.277771          0.550245
# std           6.838579e+05         0.447902          0.497472
# min           0.000000e+00         0.000000          0.000000
# 25%           5.576000e+05         0.000000          0.000000
# 50%           8.068720e+05         0.000000          1.000000
# 75%           1.157020e+06         1.000000          1.000000
# max           9.449000e+06         1.000000          1.000000
#
#        POLICY_COURT_SIGN  POLICY_HAS_COMPLAINTS  POLICY_DEDUCT_VALUE  \
# count       95352.000000           95352.000000         95352.000000
# mean            0.000965               0.007446          6036.711308
# std             0.031047               0.085969         10457.380954
# min             0.000000               0.000000             0.000000
# 25%             0.000000               0.000000             0.000000
# 50%             0.000000               0.000000             0.000000
# 75%             0.000000               0.000000         10000.000000
# max             1.000000               1.000000        120873.000000
#
#        POLICY_PRICE_CHANGE
# count         95352.000000
# mean             -0.063786
# std               0.766108
# min              -1.000000
# 25%              -0.180000
# 50%               0.000000
# 75%               0.050000
# max              60.020000

# %%
#В датафрейме есть два типа данных тестовые и тренировочные. Возмем тренировчные данные, тестовые данные не содержат целевой перменной
#Thare are two types of data - test and train. Lets take train dataset
data_train = data.loc[ data['DATA_TYPE'] == 'TRAIN' ]
data_test = data.loc[ data['DATA_TYPE'] == 'TEST ' ]

# %%
#Зададим целевую переменную POLICY_IS_RENEWED - полис был пролонгирован
#Set target variable - Policy was renewed
Y = data_train['POLICY_IS_RENEWED']

# %%
#Удалим ID полиса из обучающей выборки
#Remove policy ID from train data
data_train=data_train.drop(('POLICY_ID'), axis=1)

# %%
#Удалим целевую переменную из обучающей выборки
#Remove target variable from train data
data_train=data_train.drop(('POLICY_IS_RENEWED'), axis=1)

# %%
#Удалим тип данных из обучающей выборки
#Remove data type from train data
data_train=data_train.drop(('DATA_TYPE'), axis=1)

# %%
#Преобразуем признак изменения цены полиса в числовую переменную
#Transform POLICY_PRICE_CHANGE to numeric variable
data_train.POLICY_PRICE_CHANGE = pd.to_numeric(data_train.POLICY_PRICE_CHANGE)

# %%
#Определим по типу данных категориальные признаки и числовые для дальнейших преобразований
#Find categorical and numerical columns for further transformation
categorical_columns = [c for c in data_train.columns if data_train[c].dtype.name == 'object']
numerical_columns   = [c for c in data_train.columns if data_train[c].dtype.name != 'object']

# %%
# Посмотрим на категориальные признаки
# Have a look at categorical variables
data_train[categorical_columns].describe()
# Out:
#        POLICY_BRANCH VEHICLE_MAKE VEHICLE_MODEL POLICY_INTERMEDIARY  \
# count          76407        76407         76407               76407
# unique             2           80           525                1321
# top           Москва          Kia          RAV4                   N
# freq           40168         8754          3301               16337
#
#        INSURER_GENDER POLICY_CLM_N POLICY_CLM_GLT_N POLICY_PRV_CLM_N  \
# count           76407        76407            76407            76407
# unique              2            7                7                7
# top                 M            0                0                0
# freq            48307        54298            57688            35335
#
#        POLICY_PRV_CLM_GLT_N CLAIM_AVG_ACC_ST_PRD POLICY_YEARS_RENEWED_N  \
# count                 76407                76407                  76407
# unique                    7                  639                     12
# top                       0                    0                      0
# freq                  38137                59753                  26336
#
#        CLIENT_REGISTRATION_REGION
# count                       76407
# unique                         83
# top               Санкт-Петербург
# freq                        30717

# %%
#Заполним пропущенные значения категориальных признаков самыми популярными значениеми
#Fill fields with not available date by top values
data_describe = data_train.describe(include=[object])
for c in categorical_columns:
    data_train[c] = data_train[c].fillna(data_describe[c]['top'])

# %%
# Заполним пропущенные значения числовых признаков медианным значанием
# Fill numerical data train values by median values
data_train = data_train.fillna(data.median(axis=0), axis=0)

# %%
# Посмотрим на корреляцию между данными
# Look at variables correlation
data_train.corr()
# Out:
#                                POLICY_BEGIN_MONTH  POLICY_END_MONTH  \
# POLICY_BEGIN_MONTH                       1.000000          0.998030
# POLICY_END_MONTH                         0.998030          1.000000
# POLICY_SALES_CHANNEL                     0.004473          0.004714
# POLICY_SALES_CHANNEL_GROUP               0.016706          0.016645
# POLICY_MIN_AGE                          -0.007420         -0.007338
# POLICY_MIN_DRIVING_EXPERIENCE            0.022147          0.022516
# VEHICLE_ENGINE_POWER                     0.019350          0.019782
# VEHICLE_IN_CREDIT                        0.071432          0.071989
# VEHICLE_SUM_INSURED                      0.053374          0.054115
# CLIENT_HAS_DAGO                         -0.015745         -0.016697
# CLIENT_HAS_OSAGO                        -0.009642         -0.010289
# POLICY_COURT_SIGN                       -0.002862         -0.002664
# POLICY_HAS_COMPLAINTS                    0.002293          0.002605
# POLICY_DEDUCT_VALUE                     -0.057753         -0.057774
# POLICY_PRICE_CHANGE                     -0.001045         -0.000923
#
#                                POLICY_SALES_CHANNEL  \
# POLICY_BEGIN_MONTH                         0.004473
# POLICY_END_MONTH                           0.004714
# POLICY_SALES_CHANNEL                       1.000000
# POLICY_SALES_CHANNEL_GROUP                 0.683366
# POLICY_MIN_AGE                             0.027907
# POLICY_MIN_DRIVING_EXPERIENCE              0.010776
# VEHICLE_ENGINE_POWER                      -0.079471
# VEHICLE_IN_CREDIT                          0.129964
# VEHICLE_SUM_INSURED                       -0.029085
# CLIENT_HAS_DAGO                           -0.078392
# CLIENT_HAS_OSAGO                          -0.145705
# POLICY_COURT_SIGN                          0.002072
# POLICY_HAS_COMPLAINTS                      0.004939
# POLICY_DEDUCT_VALUE                       -0.028384
# POLICY_PRICE_CHANGE                       -0.030716
#
#                                POLICY_SALES_CHANNEL_GROUP  POLICY_MIN_AGE  \
# POLICY_BEGIN_MONTH                               0.016706       -0.007420
# POLICY_END_MONTH                                 0.016645       -0.007338
# POLICY_SALES_CHANNEL                             0.683366        0.027907
# POLICY_SALES_CHANNEL_GROUP                       1.000000        0.016360
# POLICY_MIN_AGE                                   0.016360        1.000000
# POLICY_MIN_DRIVING_EXPERIENCE                    0.021270        0.024462
# VEHICLE_ENGINE_POWER                            -0.019368       -0.063048
# VEHICLE_IN_CREDIT                                0.172941       -0.076707
# VEHICLE_SUM_INSURED                              0.045989       -0.047560
# CLIENT_HAS_DAGO                                 -0.067206       -0.093187
# CLIENT_HAS_OSAGO                                -0.168341       -0.022502
# POLICY_COURT_SIGN                               -0.003868       -0.017133
# POLICY_HAS_COMPLAINTS                           -0.001025       -0.021082
# POLICY_DEDUCT_VALUE                             -0.077879       -0.157575
# POLICY_PRICE_CHANGE                             -0.046947       -0.009067
#
#                                POLICY_MIN_DRIVING_EXPERIENCE  \
# POLICY_BEGIN_MONTH                                  0.022147
# POLICY_END_MONTH                                    0.022516
# POLICY_SALES_CHANNEL                                0.010776
# POLICY_SALES_CHANNEL_GROUP                          0.021270
# POLICY_MIN_AGE                                      0.024462
# POLICY_MIN_DRIVING_EXPERIENCE                       1.000000
# VEHICLE_ENGINE_POWER                               -0.000148
# VEHICLE_IN_CREDIT                                   0.033575
# VEHICLE_SUM_INSURED                                 0.049069
# CLIENT_HAS_DAGO                                    -0.038847
# CLIENT_HAS_OSAGO                                   -0.013643
# POLICY_COURT_SIGN                                  -0.003508
# POLICY_HAS_COMPLAINTS                              -0.000102
# POLICY_DEDUCT_VALUE                                 0.042662
# POLICY_PRICE_CHANGE                                -0.006395
#
#                                VEHICLE_ENGINE_POWER  VEHICLE_IN_CREDIT  \
# POLICY_BEGIN_MONTH                         0.019350           0.071432
# POLICY_END_MONTH                           0.019782           0.071989
# POLICY_SALES_CHANNEL                      -0.079471           0.129964
# POLICY_SALES_CHANNEL_GROUP                -0.019368           0.172941
# POLICY_MIN_AGE                            -0.063048          -0.076707
# POLICY_MIN_DRIVING_EXPERIENCE             -0.000148           0.033575
# VEHICLE_ENGINE_POWER                       1.000000          -0.067548
# VEHICLE_IN_CREDIT                         -0.067548           1.000000
# VEHICLE_SUM_INSURED                        0.777611          -0.002353
# CLIENT_HAS_DAGO                            0.040625          -0.127672
# CLIENT_HAS_OSAGO                          -0.064448          -0.082482
# POLICY_COURT_SIGN                          0.008783           0.007051
# POLICY_HAS_COMPLAINTS                      0.005008           0.003648
# POLICY_DEDUCT_VALUE                       -0.033455          -0.113565
# POLICY_PRICE_CHANGE                        0.031338          -0.041193
#
#                                VEHICLE_SUM_INSURED  CLIENT_HAS_DAGO  \
# POLICY_BEGIN_MONTH                        0.053374        -0.015745
# POLICY_END_MONTH                          0.054115        -0.016697
# POLICY_SALES_CHANNEL                     -0.029085        -0.078392
# POLICY_SALES_CHANNEL_GROUP                0.045989        -0.067206
# POLICY_MIN_AGE                           -0.047560        -0.093187
# POLICY_MIN_DRIVING_EXPERIENCE             0.049069        -0.038847
# VEHICLE_ENGINE_POWER                      0.777611         0.040625
# VEHICLE_IN_CREDIT                        -0.002353        -0.127672
# VEHICLE_SUM_INSURED                       1.000000        -0.012728
# CLIENT_HAS_DAGO                          -0.012728         1.000000
# CLIENT_HAS_OSAGO                         -0.106500         0.220065
# POLICY_COURT_SIGN                         0.015542         0.002575
# POLICY_HAS_COMPLAINTS                     0.005109         0.011710
# POLICY_DEDUCT_VALUE                      -0.060281         0.014427
# POLICY_PRICE_CHANGE                       0.007798        -0.001053
#
#                                CLIENT_HAS_OSAGO  POLICY_COURT_SIGN  \
# POLICY_BEGIN_MONTH                    -0.009642          -0.002862
# POLICY_END_MONTH                      -0.010289          -0.002664
# POLICY_SALES_CHANNEL                  -0.145705           0.002072
# POLICY_SALES_CHANNEL_GROUP            -0.168341          -0.003868
# POLICY_MIN_AGE                        -0.022502          -0.017133
# POLICY_MIN_DRIVING_EXPERIENCE         -0.013643          -0.003508
# VEHICLE_ENGINE_POWER                  -0.064448           0.008783
# VEHICLE_IN_CREDIT                     -0.082482           0.007051
# VEHICLE_SUM_INSURED                   -0.106500           0.015542
# CLIENT_HAS_DAGO                        0.220065           0.002575
# CLIENT_HAS_OSAGO                       1.000000          -0.003920
# POLICY_COURT_SIGN                     -0.003920           1.000000
# POLICY_HAS_COMPLAINTS                  0.007653           0.043877
# POLICY_DEDUCT_VALUE                    0.000540           0.004580
# POLICY_PRICE_CHANGE                    0.014715          -0.005120
#
#                                POLICY_HAS_COMPLAINTS  POLICY_DEDUCT_VALUE  \
# POLICY_BEGIN_MONTH                          0.002293            -0.057753
# POLICY_END_MONTH                            0.002605            -0.057774
# POLICY_SALES_CHANNEL                        0.004939            -0.028384
# POLICY_SALES_CHANNEL_GROUP                 -0.001025            -0.077879
# POLICY_MIN_AGE                             -0.021082            -0.157575
# POLICY_MIN_DRIVING_EXPERIENCE              -0.000102             0.042662
# VEHICLE_ENGINE_POWER                        0.005008            -0.033455
# VEHICLE_IN_CREDIT                           0.003648            -0.113565
# VEHICLE_SUM_INSURED                         0.005109            -0.060281
# CLIENT_HAS_DAGO                             0.011710             0.014427
# CLIENT_HAS_OSAGO                            0.007653             0.000540
# POLICY_COURT_SIGN                           0.043877             0.004580
# POLICY_HAS_COMPLAINTS                       1.000000            -0.010053
# POLICY_DEDUCT_VALUE                        -0.010053             1.000000
# POLICY_PRICE_CHANGE                        -0.000995            -0.025228
#
#                                POLICY_PRICE_CHANGE
# POLICY_BEGIN_MONTH                       -0.001045
# POLICY_END_MONTH                         -0.000923
# POLICY_SALES_CHANNEL                     -0.030716
# POLICY_SALES_CHANNEL_GROUP               -0.046947
# POLICY_MIN_AGE                           -0.009067
# POLICY_MIN_DRIVING_EXPERIENCE            -0.006395
# VEHICLE_ENGINE_POWER                      0.031338
# VEHICLE_IN_CREDIT                        -0.041193
# VEHICLE_SUM_INSURED                       0.007798
# CLIENT_HAS_DAGO                          -0.001053
# CLIENT_HAS_OSAGO                          0.014715
# POLICY_COURT_SIGN                        -0.005120
# POLICY_HAS_COMPLAINTS                    -0.000995
# POLICY_DEDUCT_VALUE                      -0.025228
# POLICY_PRICE_CHANGE                       1.000000

# %%
# Определим переменные с количеством категорий  2 (бинарные) и более двух (многоклассовые)
# Find variables with 2 categories and more than 2
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print ("Binary: ", binary_columns)
print("Nonbinary: ", nonbinary_columns)
# Out:
# Binary:  ['POLICY_BRANCH', 'INSURER_GENDER']
# Nonbinary:  ['VEHICLE_MAKE', 'VEHICLE_MODEL', 'POLICY_INTERMEDIARY', 'POLICY_CLM_N', 'POLICY_CLM_GLT_N', 'POLICY_PRV_CLM_N', 'POLICY_PRV_CLM_GLT_N', 'CLAIM_AVG_ACC_ST_PRD', 'POLICY_YEARS_RENEWED_N', 'CLIENT_REGISTRATION_REGION']

# %%
# Заменим значения бинарных категорий признаков на значения 0 или 1
# Change binary categroies to 0 or 1
for c in binary_columns[0:]:
    top = data_describe[c]['top']
    top_items = data_train[c] == top
    data_train.loc[top_items, c] = 0
    data_train.loc[np.logical_not(top_items), c] = 1

# %%
# Создадим новый датафрейм с категориальными признаками преобразовынными в dummy переменные 1 и 0 вместо значения каждой категории
# Create new dataframe with categorical variables transformed to dummy variable instead 
data_nonbinary = pd.get_dummies(data_train[nonbinary_columns])
print (data_nonbinary.columns)
# Out:
# Index(['VEHICLE_MAKE_<Пусто>', 'VEHICLE_MAKE_Acura', 'VEHICLE_MAKE_Alfa Romeo',
#        'VEHICLE_MAKE_Audi', 'VEHICLE_MAKE_BMW', 'VEHICLE_MAKE_BYD',
#        'VEHICLE_MAKE_Bentley', 'VEHICLE_MAKE_Bogdan',
#        'VEHICLE_MAKE_Brilliance', 'VEHICLE_MAKE_Cadillac',
#        ...
#        'CLIENT_REGISTRATION_REGION_Ульяновская',
#        'CLIENT_REGISTRATION_REGION_Хабаровский',
#        'CLIENT_REGISTRATION_REGION_Хакасия',
#        'CLIENT_REGISTRATION_REGION_Ханты-Мансийский Автономный округ - Югра',
#        'CLIENT_REGISTRATION_REGION_Челябинская',
#        'CLIENT_REGISTRATION_REGION_Чеченская',
#        'CLIENT_REGISTRATION_REGION_Чувашская Республика -',
#        'CLIENT_REGISTRATION_REGION_Чукотский',
#        'CLIENT_REGISTRATION_REGION_Ямало-Ненецкий',
#        'CLIENT_REGISTRATION_REGION_Ярославская'],
#       dtype='object', length=2688)

# %%
# Ряд алгоритмов требует нормализованного пространства признаков. Нормализуем пространство
# Some of ML algorithms need to normalise dataset
data_numerical = data_train[numerical_columns]
data_numerical = (data_numerical - data_numerical.mean()) / data_numerical.std()
data_numerical.describe()
# Out:
#        POLICY_BEGIN_MONTH  POLICY_END_MONTH  POLICY_SALES_CHANNEL  \
# count        7.640700e+04      7.640700e+04          7.640700e+04
# mean         3.200282e-15     -4.230603e-15         -7.468457e-16
# std          1.000000e+00      1.000000e+00          1.000000e+00
# min         -1.730366e+00     -1.722320e+00         -3.316435e+00
# 25%         -8.472508e-01     -8.400286e-01          1.858454e-01
# 50%          3.586461e-02      4.226298e-02          3.287956e-01
# 75%          9.189800e-01      9.245546e-01          4.002707e-01
# max          1.507724e+00      1.512749e+00          1.115022e+00
#
#        POLICY_SALES_CHANNEL_GROUP  POLICY_MIN_AGE  \
# count                7.640700e+04    7.640700e+04
# mean                -1.769577e-15   -9.476716e-17
# std                  1.000000e+00    1.000000e+00
# min                 -2.618019e+00   -2.299901e+00
# 25%                 -8.244024e-02   -8.070509e-01
# 50%                  5.514544e-01   -1.539288e-01
# 75%                  5.514544e-01    6.857996e-01
# max                  1.819244e+00    4.044713e+00
#
#        POLICY_MIN_DRIVING_EXPERIENCE  VEHICLE_ENGINE_POWER  VEHICLE_IN_CREDIT  \
# count                   7.640700e+04          7.640700e+04       7.640700e+04
# mean                   -1.613131e-16         -1.994084e-15       2.015850e-15
# std                     1.000000e+00          1.000000e+00       1.000000e+00
# min                    -1.750199e-01         -2.859027e+00      -6.859230e-01
# 25%                    -1.353427e-01         -5.736631e-01      -6.859230e-01
# 50%                    -1.055848e-01         -1.463188e-01      -6.859230e-01
# 75%                    -8.078655e-02          3.181860e-01       1.457870e+00
# max                     9.818677e+00          3.430135e+01       1.457870e+00
#
#        VEHICLE_SUM_INSURED  CLIENT_HAS_DAGO  CLIENT_HAS_OSAGO  \
# count         7.640700e+04     7.640700e+04      7.640700e+04
# mean          1.856889e-16    -4.318837e-15      3.127659e-15
# std           1.000000e+00     1.000000e+00      1.000000e+00
# min          -1.432033e+00    -6.178201e-01     -1.105773e+00
# 25%          -6.135227e-01    -6.178201e-01     -1.105773e+00
# 50%          -2.502116e-01    -6.178201e-01      9.043332e-01
# 75%           2.695888e-01     1.618573e+00      9.043332e-01
# max           1.244006e+01     1.618573e+00      9.043332e-01
#
#        POLICY_COURT_SIGN  POLICY_HAS_COMPLAINTS  POLICY_DEDUCT_VALUE  \
# count       7.640700e+04           7.640700e+04         7.640700e+04
# mean       -2.846885e-15          -3.610073e-15        -5.455403e-16
# std         1.000000e+00           1.000000e+00         1.000000e+00
# min        -3.028159e-02          -8.444466e-02        -5.775672e-01
# 25%        -3.028159e-02          -8.444466e-02        -5.775672e-01
# 50%        -3.028159e-02          -8.444466e-02        -5.775672e-01
# 75%        -3.028159e-02          -8.444466e-02         3.805021e-01
# max         3.302294e+01           1.184192e+01         1.100290e+01
#
#        POLICY_PRICE_CHANGE
# count         7.640700e+04
# mean         -1.346274e-14
# std           1.000000e+00
# min          -1.246675e+00
# 25%          -1.548110e-01
# 50%           8.486650e-02
# 75%           1.514436e-01
# max           8.000400e+01

# %%
# Объедним массивы данных и преоброзуем все значения к типу float, количество признаков вырасло с 28 до 2705
# Concatenate data arrays and transform all values to float, number of variables increase from 28 to 2705
data_model = pd.concat((data_numerical, data_train[binary_columns], data_nonbinary), axis=1)
data_model = pd.DataFrame(data_model, dtype=float)
print ("Shape: ",data_model.shape)
print ("Columns: ",data_model.columns)
# Out:
# Shape:  (76407, 2705)
# Columns:  Index(['POLICY_BEGIN_MONTH', 'POLICY_END_MONTH', 'POLICY_SALES_CHANNEL',
#        'POLICY_SALES_CHANNEL_GROUP', 'POLICY_MIN_AGE',
#        'POLICY_MIN_DRIVING_EXPERIENCE', 'VEHICLE_ENGINE_POWER',
#        'VEHICLE_IN_CREDIT', 'VEHICLE_SUM_INSURED', 'CLIENT_HAS_DAGO',
#        ...
#        'CLIENT_REGISTRATION_REGION_Ульяновская',
#        'CLIENT_REGISTRATION_REGION_Хабаровский',
#        'CLIENT_REGISTRATION_REGION_Хакасия',
#        'CLIENT_REGISTRATION_REGION_Ханты-Мансийский Автономный округ - Югра',
#        'CLIENT_REGISTRATION_REGION_Челябинская',
#        'CLIENT_REGISTRATION_REGION_Чеченская',
#        'CLIENT_REGISTRATION_REGION_Чувашская Республика -',
#        'CLIENT_REGISTRATION_REGION_Чукотский',
#        'CLIENT_REGISTRATION_REGION_Ямало-Ненецкий',
#        'CLIENT_REGISTRATION_REGION_Ярославская'],
#       dtype='object', length=2705)

# %%
# Назовем входные параметры для модели X
# Lets name X input parameters 
X = data_model.copy()
feature_names = X.columns

# %%
#Импортируем стандартный набор компопнентов бибилотеки sklearn
#Import components of sklearn library
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
# Поделим выборку для модели на 2 части - тестовую (30 процентов) - измерение качества и тренировочную (70 процентов) - построение модели.
# Split data to 2 parts - test - measure of quality and train - model building
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 11)

# %%
# Построим модель случайного леса, с числом деревьев 100 и фиксированным параметром случайности
# Build model of random forest with number of trees 100 and fixed random state = 11
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators=100, random_state=11)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=11,
#             verbose=0, warm_start=False)

# %%
# Рассчитаем различные метрики качества модели
# Calculate different quality metrics of random forest model
print("precision:",metrics.precision_score(y_test, rf.predict(X_test)))
print("recall:",metrics.recall_score(y_test, rf.predict(X_test)))
print("roc_auc:",roc_auc_score(y_test, rf.predict(X_test)))
print("gini:",2*roc_auc_score(y_test, rf.predict(X_test))-1)
print ("accuracy:",accuracy_score(y_test, rf.predict(X_test)))
# Out:
# precision: 0.7013809910641755
# recall: 0.8978162911611786
# roc_auc: 0.6244788681035358
# gini: 0.24895773620707162
# accuracy: 0.6951533394407364

# %%
# Сортируем метрики качества по степени их убывания
# Sort metrics by metrics importance

importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature importances:")
for f, idx in enumerate(indices):
    print("{:2d}. feature '{:5s}' ({:.4f})".format(f + 1, feature_names[idx], importances[idx]))
# Out:
# Feature importances:
#  1. feature 'POLICY_PRICE_CHANGE' (0.0824)
#  2. feature 'VEHICLE_SUM_INSURED' (0.0623)
#  3. feature 'POLICY_MIN_AGE' (0.0566)
#  4. feature 'POLICY_MIN_DRIVING_EXPERIENCE' (0.0537)
#  5. feature 'VEHICLE_ENGINE_POWER' (0.0439)
#  6. feature 'POLICY_BEGIN_MONTH' (0.0378)
#  7. feature 'POLICY_END_MONTH' (0.0376)
#  8. feature 'POLICY_DEDUCT_VALUE' (0.0251)
#  9. feature 'POLICY_SALES_CHANNEL' (0.0248)
# 10. feature 'INSURER_GENDER' (0.0148)
# 11. feature 'VEHICLE_IN_CREDIT' (0.0128)
# 12. feature 'CLIENT_HAS_OSAGO' (0.0126)
# 13. feature 'POLICY_SALES_CHANNEL_GROUP' (0.0124)
# 14. feature 'CLIENT_HAS_DAGO' (0.0112)
# 15. feature 'CLIENT_REGISTRATION_REGION_Санкт-Петербург' (0.0082)
# 16. feature 'CLIENT_REGISTRATION_REGION_Москва' (0.0078)
# 17. feature 'POLICY_INTERMEDIARY_N' (0.0074)
# 18. feature 'POLICY_YEARS_RENEWED_N_1' (0.0072)
# 19. feature 'POLICY_CLM_GLT_N_0' (0.0070)
# 20. feature 'CLAIM_AVG_ACC_ST_PRD_0' (0.0067)
# 21. feature 'POLICY_PRV_CLM_GLT_N_0' (0.0066)
# 22. feature 'POLICY_BRANCH' (0.0066)
# 23. feature 'POLICY_YEARS_RENEWED_N_2' (0.0065)
# 24. feature 'POLICY_PRV_CLM_N_0' (0.0061)
# 25. feature 'CLIENT_REGISTRATION_REGION_Московская' (0.0061)
# 26. feature 'POLICY_CLM_N_0' (0.0057)
# 27. feature 'POLICY_PRV_CLM_N_N' (0.0055)
# 28. feature 'POLICY_YEARS_RENEWED_N_3' (0.0055)
# 29. feature 'POLICY_INTERMEDIARY_1096' (0.0054)
# 30. feature 'POLICY_CLM_GLT_N_2' (0.0054)
# 31. feature 'POLICY_PRV_CLM_GLT_N_N' (0.0053)
# 32. feature 'VEHICLE_MAKE_Kia' (0.0053)
# 33. feature 'VEHICLE_MAKE_Hyundai' (0.0049)
# 34. feature 'VEHICLE_MAKE_Toyota' (0.0046)
# 35. feature 'VEHICLE_MAKE_Ford' (0.0045)
# 36. feature 'POLICY_YEARS_RENEWED_N_0' (0.0045)
# 37. feature 'VEHICLE_MAKE_Renault' (0.0042)
# 38. feature 'POLICY_YEARS_RENEWED_N_4' (0.0041)
# 39. feature 'VEHICLE_MAKE_Nissan' (0.0038)
# 40. feature 'VEHICLE_MAKE_Mitsubishi' (0.0037)
# 41. feature 'POLICY_PRV_CLM_N_1L' (0.0036)
# 42. feature 'CLIENT_REGISTRATION_REGION_Ленинградская' (0.0036)
# 43. feature 'POLICY_CLM_N_1L' (0.0035)
# 44. feature 'POLICY_CLM_N_1S' (0.0034)
# 45. feature 'VEHICLE_MAKE_Volkswagen' (0.0034)
# 46. feature 'POLICY_CLM_N_2' (0.0034)
# 47. feature 'POLICY_CLM_GLT_N_1S' (0.0034)
# 48. feature 'VEHICLE_MODEL_RAV4' (0.0032)
# 49. feature 'POLICY_CLM_GLT_N_1L' (0.0032)
# 50. feature 'POLICY_PRV_CLM_N_1S' (0.0032)
# 51. feature 'POLICY_PRV_CLM_GLT_N_1S' (0.0031)
# 52. feature 'VEHICLE_MODEL_Sportage' (0.0031)
# 53. feature 'VEHICLE_MAKE_Skoda' (0.0031)
# 54. feature 'VEHICLE_MODEL_Duster' (0.0030)
# 55. feature 'VEHICLE_MODEL_Focus' (0.0028)
# 56. feature 'POLICY_INTERMEDIARY_910' (0.0028)
# 57. feature 'VEHICLE_MODEL_ix35' (0.0026)
# 58. feature 'POLICY_PRV_CLM_GLT_N_1L' (0.0026)
# 59. feature 'POLICY_PRV_CLM_N_2' (0.0025)
# 60. feature 'VEHICLE_MODEL_Ceed' (0.0025)
# 61. feature 'VEHICLE_MODEL_Solaris' (0.0024)
# 62. feature 'VEHICLE_MAKE_BMW' (0.0023)
# 63. feature 'CLAIM_AVG_ACC_ST_PRD_1' (0.0022)
# 64. feature 'VEHICLE_MODEL_Qashqai' (0.0022)
# 65. feature 'VEHICLE_MODEL_Outlander' (0.0021)
# 66. feature 'VEHICLE_MODEL_Kuga' (0.0021)
# 67. feature 'VEHICLE_MODEL_Rio' (0.0020)
# 68. feature 'VEHICLE_MODEL_ASX' (0.0020)
# 69. feature 'POLICY_INTERMEDIARY_1252' (0.0020)
# 70. feature 'POLICY_CLM_GLT_N_3' (0.0019)
# 71. feature 'VEHICLE_MAKE_Opel' (0.0019)
# 72. feature 'POLICY_YEARS_RENEWED_N_5' (0.0019)
# 73. feature 'VEHICLE_MAKE_Audi' (0.0019)
# 74. feature 'VEHICLE_MODEL_Другая модель (Легковое ТС)' (0.0019)
# 75. feature 'CLIENT_REGISTRATION_REGION_N' (0.0019)
# 76. feature 'VEHICLE_MODEL_Tiguan' (0.0018)
# 77. feature 'VEHICLE_MODEL_Santa Fe' (0.0018)
# 78. feature 'POLICY_CLM_N_3' (0.0018)
# 79. feature 'POLICY_PRV_CLM_GLT_N_2' (0.0018)
# 80. feature 'VEHICLE_MAKE_Honda' (0.0018)
# 81. feature 'CLAIM_AVG_ACC_ST_PRD_2' (0.0017)
# 82. feature 'VEHICLE_MODEL_Octavia' (0.0017)
# 83. feature 'VEHICLE_MAKE_Suzuki' (0.0017)
# 84. feature 'VEHICLE_MAKE_Land Rover' (0.0016)
# 85. feature 'CLAIM_AVG_ACC_ST_PRD_3' (0.0016)
# 86. feature 'POLICY_YEARS_RENEWED_N_6' (0.0016)
# 87. feature 'VEHICLE_MAKE_Chevrolet' (0.0016)
# 88. feature 'VEHICLE_MAKE_Volvo' (0.0016)
# 89. feature 'CLAIM_AVG_ACC_ST_PRD_4' (0.0016)
# 90. feature 'VEHICLE_MODEL_X-Trail' (0.0015)
# 91. feature 'VEHICLE_MODEL_Juke' (0.0015)
# 92. feature 'VEHICLE_MODEL_Sorento' (0.0015)
# 93. feature 'POLICY_INTERMEDIARY_1221' (0.0014)
# 94. feature 'CLAIM_AVG_ACC_ST_PRD_6' (0.0014)
# 95. feature 'CLAIM_AVG_ACC_ST_PRD_5' (0.0014)
# 96. feature 'POLICY_INTERMEDIARY_326' (0.0014)
# 97. feature 'VEHICLE_MODEL_Sandero' (0.0013)
# 98. feature 'VEHICLE_MODEL_X3' (0.0013)
# 99. feature 'VEHICLE_MODEL_Grand Vitara' (0.0013)
# 100. feature 'VEHICLE_MODEL_Yeti' (0.0013)
# 101. feature 'VEHICLE_MAKE_Mazda' (0.0013)
# 102. feature 'VEHICLE_MAKE_Ssang Yong' (0.0013)
# 103. feature 'VEHICLE_MODEL_CR-V' (0.0013)
# 104. feature 'VEHICLE_MAKE_Mercedes-Benz' (0.0013)
# 105. feature 'VEHICLE_MODEL_Megane' (0.0012)
# 106. feature 'CLAIM_AVG_ACC_ST_PRD_7' (0.0012)
# 107. feature 'VEHICLE_MODEL_Fluence' (0.0012)
# 108. feature 'POLICY_INTERMEDIARY_171' (0.0012)
# 109. feature 'POLICY_INTERMEDIARY_343' (0.0012)
# 110. feature 'VEHICLE_MODEL_X1' (0.0012)
# 111. feature 'VEHICLE_MAKE_Subaru' (0.0012)
# 112. feature 'POLICY_INTERMEDIARY_493' (0.0012)
# 113. feature 'VEHICLE_MODEL_Land Cruiser Prado' (0.0012)
# 114. feature 'POLICY_HAS_COMPLAINTS' (0.0012)
# 115. feature 'POLICY_INTERMEDIARY_1200' (0.0011)
# 116. feature 'POLICY_INTERMEDIARY_1253' (0.0011)
# 117. feature 'POLICY_INTERMEDIARY_454' (0.0011)
# 118. feature 'VEHICLE_MODEL_Logan' (0.0011)
# 119. feature 'POLICY_INTERMEDIARY_565' (0.0011)
# 120. feature 'POLICY_CLM_N_4+' (0.0011)
# 121. feature 'VEHICLE_MODEL_Fabia' (0.0011)
# 122. feature 'VEHICLE_MODEL_Mondeo' (0.0011)
# 123. feature 'VEHICLE_MODEL_Camry' (0.0011)
# 124. feature 'VEHICLE_MODEL_Sandero Stepway' (0.0011)
# 125. feature 'VEHICLE_MODEL_Cerato' (0.0011)
# 126. feature 'POLICY_INTERMEDIARY_917' (0.0010)
# 127. feature 'POLICY_INTERMEDIARY_485' (0.0010)
# 128. feature 'VEHICLE_MODEL_i30' (0.0010)
# 129. feature 'VEHICLE_MAKE_Lada' (0.0010)
# 130. feature 'POLICY_INTERMEDIARY_245' (0.0010)
# 131. feature 'VEHICLE_MODEL_Rapid' (0.0010)
# 132. feature 'POLICY_INTERMEDIARY_264' (0.0010)
# 133. feature 'POLICY_INTERMEDIARY_1372' (0.0010)
# 134. feature 'POLICY_INTERMEDIARY_224' (0.0010)
# 135. feature 'POLICY_INTERMEDIARY_344' (0.0010)
# 136. feature 'VEHICLE_MODEL_Jetta' (0.0010)
# 137. feature 'CLAIM_AVG_ACC_ST_PRD_8' (0.0010)
# 138. feature 'POLICY_INTERMEDIARY_164' (0.0010)
# 139. feature 'VEHICLE_MODEL_Land Cruiser 150' (0.0010)
# 140. feature 'POLICY_YEARS_RENEWED_N_7' (0.0009)
# 141. feature 'VEHICLE_MODEL_Pajero Sport' (0.0009)
# 142. feature 'VEHICLE_MODEL_X5' (0.0009)
# 143. feature 'VEHICLE_MODEL_Highlander' (0.0009)
# 144. feature 'VEHICLE_MODEL_Pajero' (0.0009)
# 145. feature 'POLICY_PRV_CLM_N_3' (0.0009)
# 146. feature 'POLICY_INTERMEDIARY_528' (0.0009)
# 147. feature 'POLICY_CLM_GLT_N_4+' (0.0009)
# 148. feature 'VEHICLE_MAKE_ВАЗ' (0.0009)
# 149. feature 'VEHICLE_MODEL_Corolla' (0.0009)
# 150. feature 'VEHICLE_MODEL_Mokka' (0.0009)
# 151. feature 'CLAIM_AVG_ACC_ST_PRD_9' (0.0009)
# 152. feature 'POLICY_INTERMEDIARY_272' (0.0008)
# 153. feature 'VEHICLE_MODEL_Passat' (0.0008)
# 154. feature 'VEHICLE_MODEL_Explorer' (0.0008)
# 155. feature 'POLICY_INTERMEDIARY_360' (0.0008)
# 156. feature 'VEHICLE_MODEL_Golf' (0.0008)
# 157. feature 'POLICY_INTERMEDIARY_946' (0.0008)
# 158. feature 'VEHICLE_MODEL_Forester' (0.0008)
# 159. feature 'POLICY_INTERMEDIARY_641' (0.0008)
# 160. feature 'VEHICLE_MODEL_Actyon' (0.0008)
# 161. feature 'VEHICLE_MODEL_Touareg' (0.0008)
# 162. feature 'POLICY_INTERMEDIARY_509' (0.0008)
# 163. feature 'VEHICLE_MODEL_Outlander XL' (0.0008)
# 164. feature 'VEHICLE_MODEL_XC60' (0.0008)
# 165. feature 'POLICY_INTERMEDIARY_1188' (0.0007)
# 166. feature 'VEHICLE_MAKE_Peugeot' (0.0007)
# 167. feature 'POLICY_INTERMEDIARY_230' (0.0007)
# 168. feature 'VEHICLE_MODEL_Astra' (0.0007)
# 169. feature 'VEHICLE_MAKE_Jeep' (0.0007)
# 170. feature 'POLICY_INTERMEDIARY_330' (0.0007)
# 171. feature 'POLICY_INTERMEDIARY_286' (0.0007)
# 172. feature 'VEHICLE_MODEL_Kyron' (0.0007)
# 173. feature 'VEHICLE_MODEL_5-series' (0.0007)
# 174. feature 'CLAIM_AVG_ACC_ST_PRD_10' (0.0007)
# 175. feature 'POLICY_INTERMEDIARY_849' (0.0007)
# 176. feature 'VEHICLE_MODEL_Polo' (0.0007)
# 177. feature 'VEHICLE_MODEL_3-series' (0.0007)
# 178. feature 'POLICY_INTERMEDIARY_948' (0.0007)
# 179. feature 'POLICY_INTERMEDIARY_1051' (0.0007)
# 180. feature 'POLICY_INTERMEDIARY_461' (0.0006)
# 181. feature 'POLICY_INTERMEDIARY_1286' (0.0006)
# 182. feature 'POLICY_INTERMEDIARY_234' (0.0006)
# 183. feature 'POLICY_INTERMEDIARY_400' (0.0006)
# 184. feature 'CLAIM_AVG_ACC_ST_PRD_12' (0.0006)
# 185. feature 'VEHICLE_MODEL_Soul' (0.0006)
# 186. feature 'POLICY_INTERMEDIARY_1346' (0.0006)
# 187. feature 'CLAIM_AVG_ACC_ST_PRD_11' (0.0006)
# 188. feature 'VEHICLE_MODEL_XC70' (0.0006)
# 189. feature 'VEHICLE_MODEL_Q5' (0.0006)
# 190. feature 'VEHICLE_MODEL_Q3' (0.0006)
# 191. feature 'VEHICLE_MODEL_Koleos' (0.0006)
# 192. feature 'VEHICLE_MODEL_Cruze' (0.0006)
# 193. feature 'POLICY_INTERMEDIARY_585' (0.0006)
# 194. feature 'VEHICLE_MAKE_УАЗ' (0.0006)
# 195. feature 'VEHICLE_MAKE_Great Wall' (0.0006)
# 196. feature 'VEHICLE_MODEL_Hover' (0.0006)
# 197. feature 'VEHICLE_MODEL_3163 Patriot' (0.0006)
# 198. feature 'POLICY_INTERMEDIARY_296' (0.0006)
# 199. feature 'VEHICLE_MODEL_Lancer X' (0.0006)
# 200. feature 'VEHICLE_MODEL_XC90' (0.0006)
# 201. feature 'VEHICLE_MODEL_Freelander' (0.0006)
# 202. feature 'VEHICLE_MODEL_Venga' (0.0006)
# 203. feature 'VEHICLE_MODEL_Granta' (0.0006)
# 204. feature 'VEHICLE_MODEL_Largus' (0.0006)
# 205. feature 'POLICY_INTERMEDIARY_1362' (0.0006)
# 206. feature 'POLICY_INTERMEDIARY_1276' (0.0006)
# 207. feature 'POLICY_INTERMEDIARY_515' (0.0006)
# 208. feature 'VEHICLE_MODEL_SX4' (0.0005)
# 209. feature 'VEHICLE_MODEL_Optima' (0.0005)
# 210. feature 'POLICY_PRV_CLM_GLT_N_3' (0.0005)
# 211. feature 'CLIENT_REGISTRATION_REGION_Калужская' (0.0005)
# 212. feature 'CLAIM_AVG_ACC_ST_PRD_14' (0.0005)
# 213. feature 'VEHICLE_MODEL_SR' (0.0005)
# 214. feature 'CLIENT_REGISTRATION_REGION_Владимирская' (0.0005)
# 215. feature 'VEHICLE_MODEL_Range Rover Sport' (0.0005)
# 216. feature 'VEHICLE_MODEL_Note' (0.0005)
# 217. feature 'VEHICLE_MODEL_X6' (0.0005)
# 218. feature 'VEHICLE_MODEL_Fusion' (0.0005)
# 219. feature 'CLIENT_REGISTRATION_REGION_Тульская' (0.0005)
# 220. feature 'VEHICLE_MODEL_i40' (0.0005)
# 221. feature 'VEHICLE_MODEL_Elantra' (0.0005)
# 222. feature 'POLICY_INTERMEDIARY_261' (0.0005)
# 223. feature 'VEHICLE_MAKE_Citroen' (0.0005)
# 224. feature 'VEHICLE_MAKE_Lifan' (0.0005)
# 225. feature 'POLICY_INTERMEDIARY_703' (0.0005)
# 226. feature 'CLAIM_AVG_ACC_ST_PRD_13' (0.0005)
# 227. feature 'VEHICLE_MODEL_3' (0.0005)
# 228. feature 'VEHICLE_MODEL_Kangoo' (0.0005)
# 229. feature 'POLICY_INTERMEDIARY_339' (0.0005)
# 230. feature 'POLICY_INTERMEDIARY_1355' (0.0005)
# 231. feature 'VEHICLE_MODEL_Captiva' (0.0005)
# 232. feature 'POLICY_INTERMEDIARY_6' (0.0005)
# 233. feature 'VEHICLE_MODEL_Grand Cherokee' (0.0005)
# 234. feature 'POLICY_INTERMEDIARY_243' (0.0005)
# 235. feature 'VEHICLE_MODEL_Almera' (0.0005)
# 236. feature 'VEHICLE_MODEL_Murano' (0.0005)
# 237. feature 'CLAIM_AVG_ACC_ST_PRD_0.5' (0.0005)
# 238. feature 'VEHICLE_MAKE_Infiniti' (0.0005)
# 239. feature 'CLIENT_REGISTRATION_REGION_Тверская' (0.0005)
# 240. feature 'POLICY_INTERMEDIARY_381' (0.0005)
# 241. feature 'POLICY_INTERMEDIARY_782' (0.0005)
# 242. feature 'POLICY_INTERMEDIARY_288' (0.0005)
# 243. feature 'POLICY_INTERMEDIARY_1333' (0.0005)
# 244. feature 'VEHICLE_MAKE_Porsche' (0.0005)
# 245. feature 'POLICY_INTERMEDIARY_340' (0.0005)
# 246. feature 'VEHICLE_MAKE_Lexus' (0.0005)
# 247. feature 'VEHICLE_MODEL_Land Cruiser 200' (0.0005)
# 248. feature 'VEHICLE_MODEL_Range Rover' (0.0005)
# 249. feature 'POLICY_INTERMEDIARY_481' (0.0004)
# 250. feature 'VEHICLE_MODEL_Getz' (0.0004)
# 251. feature 'VEHICLE_MODEL_EcoSport' (0.0004)
# 252. feature 'VEHICLE_MODEL_CX-5' (0.0004)
# 253. feature 'VEHICLE_MODEL_Lancer' (0.0004)
# 254. feature 'POLICY_INTERMEDIARY_616' (0.0004)
# 255. feature 'POLICY_INTERMEDIARY_1315' (0.0004)
# 256. feature 'VEHICLE_MAKE_Seat' (0.0004)
# 257. feature 'POLICY_INTERMEDIARY_1199' (0.0004)
# 258. feature 'VEHICLE_MODEL_Tiida' (0.0004)
# 259. feature 'VEHICLE_MODEL_Range Rover Evoque' (0.0004)
# 260. feature 'POLICY_INTERMEDIARY_1223' (0.0004)
# 261. feature 'POLICY_INTERMEDIARY_1319' (0.0004)
# 262. feature 'VEHICLE_MODEL_6' (0.0004)
# 263. feature 'VEHICLE_MAKE_Fiat' (0.0004)
# 264. feature 'POLICY_INTERMEDIARY_437' (0.0004)
# 265. feature 'VEHICLE_MODEL_A4' (0.0004)
# 266. feature 'VEHICLE_MODEL_Discovery' (0.0004)
# 267. feature 'VEHICLE_MODEL_Picanto' (0.0004)
# 268. feature 'VEHICLE_MODEL_Pilot' (0.0004)
# 269. feature 'POLICY_INTERMEDIARY_363' (0.0004)
# 270. feature 'POLICY_INTERMEDIARY_153' (0.0004)
# 271. feature 'VEHICLE_MODEL_S-Max' (0.0004)
# 272. feature 'VEHICLE_MODEL_Lacetti' (0.0004)
# 273. feature 'POLICY_INTERMEDIARY_1142' (0.0004)
# 274. feature 'POLICY_INTERMEDIARY_1287' (0.0004)
# 275. feature 'CLIENT_REGISTRATION_REGION_Смоленская' (0.0004)
# 276. feature 'POLICY_INTERMEDIARY_516' (0.0004)
# 277. feature 'POLICY_INTERMEDIARY_1209' (0.0004)
# 278. feature 'POLICY_INTERMEDIARY_1316' (0.0004)
# 279. feature 'VEHICLE_MODEL_S60' (0.0004)
# 280. feature 'CLAIM_AVG_ACC_ST_PRD_15' (0.0004)
# 281. feature 'VEHICLE_MODEL_X60' (0.0004)
# 282. feature 'VEHICLE_MODEL_Tucson' (0.0004)
# 283. feature 'VEHICLE_MODEL_Q7' (0.0004)
# 284. feature 'VEHICLE_MODEL_Antara' (0.0004)
# 285. feature 'POLICY_INTERMEDIARY_469' (0.0004)
# 286. feature 'VEHICLE_MODEL_Superb' (0.0004)
# 287. feature 'POLICY_INTERMEDIARY_682' (0.0004)
# 288. feature 'POLICY_INTERMEDIARY_1366' (0.0004)
# 289. feature 'VEHICLE_MODEL_Teana' (0.0004)
# 290. feature 'POLICY_INTERMEDIARY_260' (0.0004)
# 291. feature 'CLAIM_AVG_ACC_ST_PRD_01.май' (0.0004)
# 292. feature 'POLICY_INTERMEDIARY_951' (0.0004)
# 293. feature 'POLICY_INTERMEDIARY_204' (0.0004)
# 294. feature 'POLICY_INTERMEDIARY_1241' (0.0004)
# 295. feature 'VEHICLE_MODEL_A6' (0.0004)
# 296. feature 'CLAIM_AVG_ACC_ST_PRD_16' (0.0004)
# 297. feature 'VEHICLE_MAKE_Chery' (0.0004)
# 298. feature 'VEHICLE_MODEL_CX-7' (0.0004)
# 299. feature 'POLICY_INTERMEDIARY_244' (0.0004)
# 300. feature 'POLICY_INTERMEDIARY_674' (0.0004)
# 301. feature 'VEHICLE_MODEL_Auris' (0.0004)
# 302. feature 'POLICY_INTERMEDIARY_2' (0.0004)
# 303. feature 'POLICY_INTERMEDIARY_586' (0.0004)
# 304. feature 'VEHICLE_MODEL_A3' (0.0004)
# 305. feature 'VEHICLE_MODEL_Cayenne' (0.0004)
# 306. feature 'VEHICLE_MODEL_GL' (0.0004)
# 307. feature 'POLICY_INTERMEDIARY_94' (0.0004)
# 308. feature 'VEHICLE_MODEL_Civic' (0.0003)
# 309. feature 'VEHICLE_MODEL_Zafira' (0.0003)
# 310. feature 'VEHICLE_MODEL_Galaxy' (0.0003)
# 311. feature 'POLICY_INTERMEDIARY_352' (0.0003)
# 312. feature 'CLAIM_AVG_ACC_ST_PRD_02.май' (0.0003)
# 313. feature 'CLAIM_AVG_ACC_ST_PRD_03.май' (0.0003)
# 314. feature 'VEHICLE_MODEL_Outback' (0.0003)
# 315. feature 'CLAIM_AVG_ACC_ST_PRD_20' (0.0003)
# 316. feature 'VEHICLE_MODEL_Pathfinder' (0.0003)
# 317. feature 'CLIENT_REGISTRATION_REGION_Новгородская' (0.0003)
# 318. feature 'VEHICLE_MODEL_GLK' (0.0003)
# 319. feature 'POLICY_INTERMEDIARY_1211' (0.0003)
# 320. feature 'VEHICLE_MODEL_308' (0.0003)
# 321. feature 'POLICY_INTERMEDIARY_190' (0.0003)
# 322. feature 'VEHICLE_MODEL_Corsa' (0.0003)
# 323. feature 'VEHICLE_MODEL_Orlando' (0.0003)
# 324. feature 'CLAIM_AVG_ACC_ST_PRD_17' (0.0003)
# 325. feature 'POLICY_INTERMEDIARY_924' (0.0003)
# 326. feature 'POLICY_INTERMEDIARY_709' (0.0003)
# 327. feature 'POLICY_INTERMEDIARY_1274' (0.0003)
# 328. feature 'CLIENT_REGISTRATION_REGION_Псковская' (0.0003)
# 329. feature 'VEHICLE_MODEL_Caddy' (0.0003)
# 330. feature 'VEHICLE_MODEL_Verso' (0.0003)
# 331. feature 'POLICY_INTERMEDIARY_229' (0.0003)
# 332. feature 'POLICY_INTERMEDIARY_1369' (0.0003)
# 333. feature 'VEHICLE_MODEL_Другая модель (Грузовое ТС)' (0.0003)
# 334. feature 'POLICY_INTERMEDIARY_580' (0.0003)
# 335. feature 'VEHICLE_MODEL_Aveo' (0.0003)
# 336. feature 'CLAIM_AVG_ACC_ST_PRD_21' (0.0003)
# 337. feature 'POLICY_INTERMEDIARY_1401' (0.0003)
# 338. feature 'POLICY_INTERMEDIARY_1338' (0.0003)
# 339. feature 'POLICY_INTERMEDIARY_967' (0.0003)
# 340. feature 'POLICY_INTERMEDIARY_826' (0.0003)
# 341. feature 'POLICY_INTERMEDIARY_406' (0.0003)
# 342. feature 'POLICY_INTERMEDIARY_686' (0.0003)
# 343. feature 'CLAIM_AVG_ACC_ST_PRD_04.май' (0.0003)
# 344. feature 'VEHICLE_MODEL_Ranger' (0.0003)
# 345. feature 'POLICY_INTERMEDIARY_239' (0.0003)
# 346. feature 'POLICY_INTERMEDIARY_1037' (0.0003)
# 347. feature 'VEHICLE_MODEL_Hilux' (0.0003)
# 348. feature 'POLICY_INTERMEDIARY_1173' (0.0003)
# 349. feature 'VEHICLE_MODEL_Transit' (0.0003)
# 350. feature 'VEHICLE_MODEL_C' (0.0003)
# 351. feature 'CLAIM_AVG_ACC_ST_PRD_18' (0.0003)
# 352. feature 'VEHICLE_MODEL_Tiggo (T11)' (0.0003)
# 353. feature 'CLAIM_AVG_ACC_ST_PRD_05.май' (0.0003)
# 354. feature 'POLICY_INTERMEDIARY_1250' (0.0003)
# 355. feature 'POLICY_INTERMEDIARY_297' (0.0003)
# 356. feature 'VEHICLE_MODEL_Meriva' (0.0003)
# 357. feature 'VEHICLE_MODEL_1-series' (0.0003)
# 358. feature 'POLICY_INTERMEDIARY_533' (0.0003)
# 359. feature 'VEHICLE_MODEL_RX' (0.0003)
# 360. feature 'POLICY_INTERMEDIARY_174' (0.0003)
# 361. feature 'POLICY_INTERMEDIARY_293' (0.0003)
# 362. feature 'CLAIM_AVG_ACC_ST_PRD_27' (0.0003)
# 363. feature 'VEHICLE_MAKE_Geely' (0.0003)
# 364. feature 'POLICY_INTERMEDIARY_294' (0.0003)
# 365. feature 'POLICY_PRV_CLM_N_4+' (0.0003)
# 366. feature 'CLIENT_REGISTRATION_REGION_Нижегородская' (0.0003)
# 367. feature 'POLICY_COURT_SIGN' (0.0003)
# 368. feature 'POLICY_INTERMEDIARY_519' (0.0003)
# 369. feature 'POLICY_INTERMEDIARY_1397' (0.0002)
# 370. feature 'CLAIM_AVG_ACC_ST_PRD_19' (0.0002)
# 371. feature 'POLICY_INTERMEDIARY_33' (0.0002)
# 372. feature 'VEHICLE_MODEL_Fiesta' (0.0002)
# 373. feature 'POLICY_INTERMEDIARY_1357' (0.0002)
# 374. feature 'VEHICLE_MODEL_Golf Plus' (0.0002)
# 375. feature 'CLAIM_AVG_ACC_ST_PRD_29' (0.0002)
# 376. feature 'POLICY_INTERMEDIARY_1214' (0.0002)
# 377. feature 'POLICY_INTERMEDIARY_1063' (0.0002)
# 378. feature 'CLIENT_REGISTRATION_REGION_Мурманская' (0.0002)
# 379. feature 'POLICY_INTERMEDIARY_66' (0.0002)
# 380. feature 'CLIENT_REGISTRATION_REGION_Карелия' (0.0002)
# 381. feature 'VEHICLE_MODEL_Scenic' (0.0002)
# 382. feature 'POLICY_INTERMEDIARY_1238' (0.0002)
# 383. feature 'VEHICLE_MODEL_Accord' (0.0002)
# 384. feature 'CLIENT_REGISTRATION_REGION_Самарская' (0.0002)
# 385. feature 'CLIENT_REGISTRATION_REGION_Саратовская' (0.0002)
# 386. feature 'VEHICLE_MODEL_Leon' (0.0002)
# 387. feature 'POLICY_INTERMEDIARY_399' (0.0002)
# 388. feature 'CLIENT_REGISTRATION_REGION_Волгоградская' (0.0002)
# 389. feature 'POLICY_INTERMEDIARY_292' (0.0002)
# 390. feature 'POLICY_INTERMEDIARY_34' (0.0002)
# 391. feature 'POLICY_INTERMEDIARY_238' (0.0002)
# 392. feature 'CLAIM_AVG_ACC_ST_PRD_32' (0.0002)
# 393. feature 'CLIENT_REGISTRATION_REGION_Брянская' (0.0002)
# 394. feature 'VEHICLE_MODEL_C-Max' (0.0002)
# 395. feature 'POLICY_INTERMEDIARY_7' (0.0002)
# 396. feature 'POLICY_INTERMEDIARY_376' (0.0002)
# 397. feature 'POLICY_INTERMEDIARY_1257' (0.0002)
# 398. feature 'VEHICLE_MODEL_Venza' (0.0002)
# 399. feature 'POLICY_INTERMEDIARY_3' (0.0002)
# 400. feature 'CLAIM_AVG_ACC_ST_PRD_34' (0.0002)
# 401. feature 'CLAIM_AVG_ACC_ST_PRD_30' (0.0002)
# 402. feature 'POLICY_INTERMEDIARY_321' (0.0002)
# 403. feature 'CLAIM_AVG_ACC_ST_PRD_24' (0.0002)
# 404. feature 'POLICY_INTERMEDIARY_412' (0.0002)
# 405. feature 'VEHICLE_MODEL_C4' (0.0002)
# 406. feature 'VEHICLE_MAKE_Daewoo' (0.0002)
# 407. feature 'CLAIM_AVG_ACC_ST_PRD_22' (0.0002)
# 408. feature 'CLIENT_REGISTRATION_REGION_Ивановская' (0.0002)
# 409. feature 'VEHICLE_MODEL_Sentra' (0.0002)
# 410. feature 'VEHICLE_MODEL_Insignia' (0.0002)
# 411. feature 'CLIENT_REGISTRATION_REGION_Рязанская' (0.0002)
# 412. feature 'CLAIM_AVG_ACC_ST_PRD_06.май' (0.0002)
# 413. feature 'VEHICLE_MODEL_ML' (0.0002)
# 414. feature 'CLAIM_AVG_ACC_ST_PRD_28' (0.0002)
# 415. feature 'VEHICLE_MODEL_Doblo' (0.0002)
# 416. feature 'VEHICLE_MODEL_ix55' (0.0002)
# 417. feature 'CLAIM_AVG_ACC_ST_PRD_07.май' (0.0002)
# 418. feature 'CLAIM_AVG_ACC_ST_PRD_23' (0.0002)
# 419. feature 'VEHICLE_MODEL_3-series GT' (0.0002)
# 420. feature 'VEHICLE_MODEL_1117 Kalina' (0.0002)
# 421. feature 'POLICY_INTERMEDIARY_1244' (0.0002)
# 422. feature 'POLICY_INTERMEDIARY_167' (0.0002)
# 423. feature 'POLICY_INTERMEDIARY_1151' (0.0002)
# 424. feature 'POLICY_INTERMEDIARY_149' (0.0002)
# 425. feature 'VEHICLE_MODEL_7-series' (0.0002)
# 426. feature 'POLICY_INTERMEDIARY_998' (0.0002)
# 427. feature 'POLICY_INTERMEDIARY_396' (0.0002)
# 428. feature 'POLICY_INTERMEDIARY_96' (0.0002)
# 429. feature 'CLAIM_AVG_ACC_ST_PRD_33' (0.0002)
# 430. feature 'CLIENT_REGISTRATION_REGION_Тамбовская' (0.0002)
# 431. feature 'POLICY_INTERMEDIARY_139' (0.0002)
# 432. feature 'VEHICLE_MODEL_Master' (0.0002)
# 433. feature 'POLICY_INTERMEDIARY_205' (0.0002)
# 434. feature 'POLICY_INTERMEDIARY_1323' (0.0002)
# 435. feature 'POLICY_INTERMEDIARY_1278' (0.0002)
# 436. feature 'POLICY_INTERMEDIARY_1034' (0.0002)
# 437. feature 'CLAIM_AVG_ACC_ST_PRD_26' (0.0002)
# 438. feature 'VEHICLE_MODEL_Impreza XV' (0.0002)
# 439. feature 'CLAIM_AVG_ACC_ST_PRD_08.май' (0.0002)
# 440. feature 'CLAIM_AVG_ACC_ST_PRD_36' (0.0002)
# 441. feature 'VEHICLE_MODEL_2121' (0.0002)
# 442. feature 'POLICY_INTERMEDIARY_55' (0.0002)
# 443. feature 'POLICY_INTERMEDIARY_348' (0.0002)
# 444. feature 'POLICY_INTERMEDIARY_1292' (0.0002)
# 445. feature 'CLIENT_REGISTRATION_REGION_Башкортостан' (0.0002)
# 446. feature 'POLICY_INTERMEDIARY_1219' (0.0002)
# 447. feature 'POLICY_INTERMEDIARY_267' (0.0002)
# 448. feature 'POLICY_INTERMEDIARY_494' (0.0002)
# 449. feature 'POLICY_INTERMEDIARY_289' (0.0002)
# 450. feature 'VEHICLE_MAKE_Cadillac' (0.0002)
# 451. feature 'POLICY_INTERMEDIARY_67' (0.0002)
# 452. feature 'POLICY_INTERMEDIARY_1156' (0.0002)
# 453. feature 'VEHICLE_MODEL_E' (0.0002)
# 454. feature 'POLICY_INTERMEDIARY_1308' (0.0002)
# 455. feature 'POLICY_YEARS_RENEWED_N_8' (0.0002)
# 456. feature 'POLICY_INTERMEDIARY_157' (0.0002)
# 457. feature 'CLAIM_AVG_ACC_ST_PRD_35' (0.0002)
# 458. feature 'POLICY_INTERMEDIARY_1167' (0.0002)
# 459. feature 'POLICY_INTERMEDIARY_1258' (0.0002)
# 460. feature 'POLICY_INTERMEDIARY_181' (0.0002)
# 461. feature 'CLIENT_REGISTRATION_REGION_Мордовия' (0.0002)
# 462. feature 'POLICY_INTERMEDIARY_287' (0.0002)
# 463. feature 'POLICY_INTERMEDIARY_328' (0.0002)
# 464. feature 'POLICY_INTERMEDIARY_335' (0.0002)
# 465. feature 'POLICY_INTERMEDIARY_1326' (0.0002)
# 466. feature 'VEHICLE_MODEL_4-series' (0.0002)
# 467. feature 'CLAIM_AVG_ACC_ST_PRD_31' (0.0002)
# 468. feature 'POLICY_INTERMEDIARY_143' (0.0002)
# 469. feature 'POLICY_INTERMEDIARY_1370' (0.0002)
# 470. feature 'VEHICLE_MODEL_Swift' (0.0002)
# 471. feature 'POLICY_INTERMEDIARY_187' (0.0002)
# 472. feature 'VEHICLE_MODEL_Sonata' (0.0002)
# 473. feature 'VEHICLE_MODEL_Nexia' (0.0002)
# 474. feature 'POLICY_INTERMEDIARY_320' (0.0002)
# 475. feature 'POLICY_INTERMEDIARY_89' (0.0002)
# 476. feature 'VEHICLE_MODEL_A1' (0.0002)
# 477. feature 'VEHICLE_MODEL_A4 Allroad' (0.0002)
# 478. feature 'POLICY_INTERMEDIARY_251' (0.0002)
# 479. feature 'VEHICLE_MODEL_L 200' (0.0002)
# 480. feature 'VEHICLE_MODEL_B' (0.0002)
# 481. feature 'VEHICLE_MODEL_Berlingo' (0.0002)
# 482. feature 'POLICY_INTERMEDIARY_364' (0.0002)
# 483. feature 'VEHICLE_MODEL_Avensis' (0.0002)
# 484. feature 'VEHICLE_MODEL_A5' (0.0002)
# 485. feature 'VEHICLE_MODEL_QX70' (0.0002)
# 486. feature 'POLICY_PRV_CLM_GLT_N_4+' (0.0002)
# 487. feature 'POLICY_INTERMEDIARY_1245' (0.0002)
# 488. feature 'CLIENT_REGISTRATION_REGION_Белгородская' (0.0002)
# 489. feature 'VEHICLE_MODEL_Symbol' (0.0002)
# 490. feature 'POLICY_INTERMEDIARY_513' (0.0002)
# 491. feature 'POLICY_INTERMEDIARY_1193' (0.0001)
# 492. feature 'VEHICLE_MODEL_Touran' (0.0001)
# 493. feature 'VEHICLE_MODEL_QX80' (0.0001)
# 494. feature 'CLAIM_AVG_ACC_ST_PRD_37' (0.0001)
# 495. feature 'VEHICLE_MODEL_Tingo' (0.0001)
# 496. feature 'POLICY_INTERMEDIARY_702' (0.0001)
# 497. feature 'POLICY_INTERMEDIARY_319' (0.0001)
# 498. feature 'VEHICLE_MODEL_Amarok' (0.0001)
# 499. feature 'VEHICLE_MODEL_3008' (0.0001)
# 500. feature 'POLICY_INTERMEDIARY_1406' (0.0001)
# 501. feature 'VEHICLE_MODEL_1119 Kalina' (0.0001)
# 502. feature 'POLICY_INTERMEDIARY_1224' (0.0001)
# 503. feature 'POLICY_INTERMEDIARY_648' (0.0001)
# 504. feature 'VEHICLE_MODEL_2172 Priora' (0.0001)
# 505. feature 'VEHICLE_MODEL_A6 Allroad' (0.0001)
# 506. feature 'CLAIM_AVG_ACC_ST_PRD_25' (0.0001)
# 507. feature 'POLICY_INTERMEDIARY_1070' (0.0001)
# 508. feature 'VEHICLE_MODEL_H-1' (0.0001)
# 509. feature 'VEHICLE_MODEL_Colt' (0.0001)
# 510. feature 'POLICY_INTERMEDIARY_1158' (0.0001)
# 511. feature 'CLIENT_REGISTRATION_REGION_Ярославская' (0.0001)
# 512. feature 'VEHICLE_MAKE_Mini' (0.0001)
# 513. feature 'POLICY_INTERMEDIARY_329' (0.0001)
# 514. feature 'CLIENT_REGISTRATION_REGION_Свердловская' (0.0001)
# 515. feature 'POLICY_INTERMEDIARY_1227' (0.0001)
# 516. feature 'VEHICLE_MODEL_Ibiza' (0.0001)
# 517. feature 'CLIENT_REGISTRATION_REGION_Ростовская' (0.0001)
# 518. feature 'VEHICLE_MODEL_Ducato' (0.0001)
# 519. feature 'VEHICLE_MODEL_Caravelle' (0.0001)
# 520. feature 'POLICY_INTERMEDIARY_511' (0.0001)
# 521. feature 'CLIENT_REGISTRATION_REGION_Пензенская' (0.0001)
# 522. feature 'POLICY_INTERMEDIARY_1020' (0.0001)
# 523. feature 'POLICY_INTERMEDIARY_252' (0.0001)
# 524. feature 'POLICY_INTERMEDIARY_1189' (0.0001)
# 525. feature 'POLICY_INTERMEDIARY_160' (0.0001)
# 526. feature 'VEHICLE_MODEL_Rexton' (0.0001)
# 527. feature 'POLICY_INTERMEDIARY_489' (0.0001)
# 528. feature 'POLICY_INTERMEDIARY_110' (0.0001)
# 529. feature 'POLICY_INTERMEDIARY_587' (0.0001)
# 530. feature 'POLICY_INTERMEDIARY_956' (0.0001)
# 531. feature 'VEHICLE_MODEL_Gentra' (0.0001)
# 532. feature 'POLICY_INTERMEDIARY_881' (0.0001)
# 533. feature 'CLIENT_REGISTRATION_REGION_Ставропольский' (0.0001)
# 534. feature 'POLICY_INTERMEDIARY_947' (0.0001)
# 535. feature 'POLICY_INTERMEDIARY_1330' (0.0001)
# 536. feature 'CLIENT_REGISTRATION_REGION_Курская' (0.0001)
# 537. feature 'VEHICLE_MODEL_Mohave' (0.0001)
# 538. feature 'CLIENT_REGISTRATION_REGION_Новосибирская' (0.0001)
# 539. feature 'VEHICLE_MODEL_Cherokee' (0.0001)
# 540. feature 'CLAIM_AVG_ACC_ST_PRD_10.май' (0.0001)
# 541. feature 'POLICY_INTERMEDIARY_1191' (0.0001)
# 542. feature 'VEHICLE_MODEL_4007' (0.0001)
# 543. feature 'VEHICLE_MODEL_A8' (0.0001)
# 544. feature 'VEHICLE_MODEL_Impreza' (0.0001)
# 545. feature 'POLICY_INTERMEDIARY_804' (0.0001)
# 546. feature 'VEHICLE_MAKE_Jaguar' (0.0001)
# 547. feature 'CLAIM_AVG_ACC_ST_PRD_11.май' (0.0001)
# 548. feature 'CLAIM_AVG_ACC_ST_PRD_15.май' (0.0001)
# 549. feature 'POLICY_INTERMEDIARY_56' (0.0001)
# 550. feature 'VEHICLE_MAKE_Dodge' (0.0001)
# 551. feature 'POLICY_INTERMEDIARY_602' (0.0001)
# 552. feature 'VEHICLE_MODEL_A7' (0.0001)
# 553. feature 'POLICY_INTERMEDIARY_1194' (0.0001)
# 554. feature 'VEHICLE_MODEL_Compass' (0.0001)
# 555. feature 'POLICY_INTERMEDIARY_952' (0.0001)
# 556. feature 'CLAIM_AVG_ACC_ST_PRD_42' (0.0001)
# 557. feature 'POLICY_INTERMEDIARY_135' (0.0001)
# 558. feature 'VEHICLE_MODEL_5-series GT' (0.0001)
# 559. feature 'CLIENT_REGISTRATION_REGION_Орловская' (0.0001)
# 560. feature 'POLICY_INTERMEDIARY_1157' (0.0001)
# 561. feature 'VEHICLE_MODEL_217130 Priora' (0.0001)
# 562. feature 'CLAIM_AVG_ACC_ST_PRD_43' (0.0001)
# 563. feature 'POLICY_INTERMEDIARY_570' (0.0001)
# 564. feature 'POLICY_INTERMEDIARY_1083' (0.0001)
# 565. feature 'POLICY_INTERMEDIARY_965' (0.0001)
# 566. feature 'VEHICLE_MODEL_C-Crosser' (0.0001)
# 567. feature 'POLICY_INTERMEDIARY_1022' (0.0001)
# 568. feature 'VEHICLE_MODEL_Stavic' (0.0001)
# 569. feature 'VEHICLE_MODEL_Viano' (0.0001)
# 570. feature 'CLAIM_AVG_ACC_ST_PRD_38' (0.0001)
# 571. feature 'VEHICLE_MODEL_Accent' (0.0001)
# 572. feature 'POLICY_INTERMEDIARY_652' (0.0001)
# 573. feature 'VEHICLE_MODEL_Emgrand' (0.0001)
# 574. feature 'POLICY_INTERMEDIARY_129' (0.0001)
# 575. feature 'POLICY_INTERMEDIARY_583' (0.0001)
# 576. feature 'VEHICLE_MODEL_Grand Santa Fe' (0.0001)
# 577. feature 'CLIENT_REGISTRATION_REGION_Воронежская' (0.0001)
# 578. feature 'CLAIM_AVG_ACC_ST_PRD_09.май' (0.0001)
# 579. feature 'CLAIM_AVG_ACC_ST_PRD_14.май' (0.0001)
# 580. feature 'VEHICLE_MODEL_Tahoe' (0.0001)
# 581. feature 'CLIENT_REGISTRATION_REGION_Калининградская' (0.0001)
# 582. feature 'VEHICLE_MAKE_Vortex' (0.0001)
# 583. feature 'VEHICLE_MODEL_SRX' (0.0001)
# 584. feature 'VEHICLE_MODEL_Niva' (0.0001)
# 585. feature 'POLICY_INTERMEDIARY_74' (0.0001)
# 586. feature 'POLICY_INTERMEDIARY_186' (0.0001)
# 587. feature 'POLICY_INTERMEDIARY_16' (0.0001)
# 588. feature 'CLIENT_REGISTRATION_REGION_Татарстан' (0.0001)
# 589. feature 'POLICY_INTERMEDIARY_1058' (0.0001)
# 590. feature 'VEHICLE_MODEL_2115' (0.0001)
# 591. feature 'POLICY_INTERMEDIARY_584' (0.0001)
# 592. feature 'POLICY_INTERMEDIARY_496' (0.0001)
# 593. feature 'CLIENT_REGISTRATION_REGION_Архангельская' (0.0001)
# 594. feature 'VEHICLE_MODEL_Altea' (0.0001)
# 595. feature 'CLAIM_AVG_ACC_ST_PRD_63' (0.0001)
# 596. feature 'POLICY_INTERMEDIARY_795' (0.0001)
# 597. feature 'POLICY_INTERMEDIARY_1181' (0.0001)
# 598. feature 'POLICY_INTERMEDIARY_51' (0.0001)
# 599. feature 'VEHICLE_MAKE_ГАЗ' (0.0001)
# 600. feature 'VEHICLE_MODEL_DS4' (0.0001)
# 601. feature 'POLICY_INTERMEDIARY_401' (0.0001)
# 602. feature 'CLIENT_REGISTRATION_REGION_Красноярский' (0.0001)
# 603. feature 'POLICY_INTERMEDIARY_1163' (0.0001)
# 604. feature 'POLICY_INTERMEDIARY_1312' (0.0001)
# 605. feature 'VEHICLE_MODEL_G' (0.0001)
# 606. feature 'POLICY_INTERMEDIARY_645' (0.0001)
# 607. feature 'POLICY_INTERMEDIARY_1217' (0.0001)
# 608. feature 'POLICY_INTERMEDIARY_675' (0.0001)
# 609. feature 'POLICY_INTERMEDIARY_1131' (0.0001)
# 610. feature 'VEHICLE_MODEL_Santa Fe Classic' (0.0001)
# 611. feature 'VEHICLE_MODEL_2171 Priora' (0.0001)
# 612. feature 'POLICY_INTERMEDIARY_117' (0.0001)
# 613. feature 'POLICY_INTERMEDIARY_60' (0.0001)
# 614. feature 'CLAIM_AVG_ACC_ST_PRD_56' (0.0001)
# 615. feature 'VEHICLE_MODEL_6-series' (0.0001)
# 616. feature 'VEHICLE_MODEL_Roomster' (0.0001)
# 617. feature 'POLICY_INTERMEDIARY_834' (0.0001)
# 618. feature 'CLAIM_AVG_ACC_ST_PRD_64' (0.0001)
# 619. feature 'VEHICLE_MODEL_XV' (0.0001)
# 620. feature 'VEHICLE_MODEL_Jimny' (0.0001)
# 621. feature 'CLAIM_AVG_ACC_ST_PRD_12.май' (0.0001)
# 622. feature 'POLICY_INTERMEDIARY_678' (0.0001)
# 623. feature 'POLICY_INTERMEDIARY_708' (0.0001)
# 624. feature 'VEHICLE_MODEL_Boxer' (0.0001)
# 625. feature 'VEHICLE_MODEL_408' (0.0001)
# 626. feature 'POLICY_INTERMEDIARY_622' (0.0001)
# 627. feature 'POLICY_INTERMEDIARY_1255' (0.0001)
# 628. feature 'VEHICLE_MODEL_Jazz' (0.0001)
# 629. feature 'CLAIM_AVG_ACC_ST_PRD_61' (0.0001)
# 630. feature 'CLAIM_AVG_ACC_ST_PRD_62' (0.0001)
# 631. feature 'POLICY_INTERMEDIARY_236' (0.0001)
# 632. feature 'CLAIM_AVG_ACC_ST_PRD_18.май' (0.0001)
# 633. feature 'POLICY_INTERMEDIARY_338' (0.0001)
# 634. feature 'POLICY_INTERMEDIARY_322' (0.0001)
# 635. feature 'CLAIM_AVG_ACC_ST_PRD_39' (0.0001)
# 636. feature 'POLICY_INTERMEDIARY_1225' (0.0001)
# 637. feature 'POLICY_INTERMEDIARY_64' (0.0001)
# 638. feature 'POLICY_INTERMEDIARY_1352' (0.0001)
# 639. feature 'VEHICLE_MAKE_Другая марка (Иностранного производства)' (0.0001)
# 640. feature 'POLICY_INTERMEDIARY_1383' (0.0001)
# 641. feature 'VEHICLE_MAKE_Другая марка (Отечественного производства)' (0.0001)
# 642. feature 'VEHICLE_MODEL_M3' (0.0001)
# 643. feature 'POLICY_INTERMEDIARY_202' (0.0001)
# 644. feature 'CLIENT_REGISTRATION_REGION_Костромская' (0.0001)
# 645. feature 'CLAIM_AVG_ACC_ST_PRD_49' (0.0001)
# 646. feature 'VEHICLE_MODEL_Clio' (0.0001)
# 647. feature 'VEHICLE_MODEL_EX' (0.0001)
# 648. feature 'VEHICLE_MODEL_207' (0.0001)
# 649. feature 'POLICY_INTERMEDIARY_1023' (0.0001)
# 650. feature 'CLAIM_AVG_ACC_ST_PRD_57' (0.0001)
# 651. feature 'VEHICLE_MODEL_2114' (0.0001)
# 652. feature 'VEHICLE_MAKE_Chrysler' (0.0001)
# 653. feature 'CLIENT_REGISTRATION_REGION_Астраханская' (0.0001)
# 654. feature 'VEHICLE_MODEL_Tourneo' (0.0001)
# 655. feature 'POLICY_INTERMEDIARY_1122' (0.0001)
# 656. feature 'POLICY_INTERMEDIARY_82' (0.0001)
# 657. feature 'VEHICLE_MODEL_Partner' (0.0001)
# 658. feature 'VEHICLE_MODEL_S40' (0.0001)
# 659. feature 'VEHICLE_MODEL_C30' (0.0001)
# 660. feature 'POLICY_YEARS_RENEWED_N_9' (0.0001)
# 661. feature 'POLICY_INTERMEDIARY_704' (0.0001)
# 662. feature 'VEHICLE_MODEL_C3' (0.0001)
# 663. feature 'VEHICLE_MODEL_Land Cruiser 100' (0.0001)
# 664. feature 'VEHICLE_MODEL_Cooper S' (0.0001)
# 665. feature 'POLICY_INTERMEDIARY_1290' (0.0001)
# 666. feature 'VEHICLE_MODEL_Patrol' (0.0001)
# 667. feature 'CLAIM_AVG_ACC_ST_PRD_44' (0.0001)
# 668. feature 'CLAIM_AVG_ACC_ST_PRD_41' (0.0001)
# 669. feature 'POLICY_INTERMEDIARY_1403' (0.0001)
# 670. feature 'VEHICLE_MODEL_Trailblazer' (0.0001)
# 671. feature 'CLIENT_REGISTRATION_REGION_Калмыкия' (0.0001)
# 672. feature 'CLAIM_AVG_ACC_ST_PRD_40' (0.0001)
# 673. feature 'CLIENT_REGISTRATION_REGION_Краснодарский' (0.0001)
# 674. feature 'POLICY_INTERMEDIARY_895' (0.0001)
# 675. feature 'VEHICLE_MODEL_QX56' (0.0001)
# 676. feature 'VEHICLE_MODEL_217030 Priora' (0.0001)
# 677. feature 'POLICY_INTERMEDIARY_1154' (0.0001)
# 678. feature 'POLICY_INTERMEDIARY_1331' (0.0001)
# 679. feature 'POLICY_INTERMEDIARY_1218' (0.0001)
# 680. feature 'POLICY_INTERMEDIARY_490' (0.0001)
# 681. feature 'POLICY_INTERMEDIARY_647' (0.0001)
# 682. feature 'POLICY_INTERMEDIARY_614' (0.0001)
# 683. feature 'CLAIM_AVG_ACC_ST_PRD_1.666666667' (0.0001)
# 684. feature 'POLICY_YEARS_RENEWED_N_N' (0.0001)
# 685. feature 'CLAIM_AVG_ACC_ST_PRD_69' (0.0001)
# 686. feature 'CLIENT_REGISTRATION_REGION_Чувашская Республика -' (0.0001)
# 687. feature 'VEHICLE_MODEL_2192 Kalina' (0.0001)
# 688. feature 'POLICY_INTERMEDIARY_1296' (0.0001)
# 689. feature 'POLICY_INTERMEDIARY_332' (0.0001)
# 690. feature 'POLICY_INTERMEDIARY_57' (0.0001)
# 691. feature 'CLAIM_AVG_ACC_ST_PRD_50' (0.0001)
# 692. feature 'POLICY_INTERMEDIARY_1092' (0.0001)
# 693. feature 'POLICY_INTERMEDIARY_471' (0.0001)
# 694. feature 'VEHICLE_MODEL_Edge' (0.0001)
# 695. feature 'CLIENT_REGISTRATION_REGION_Липецкая' (0.0001)
# 696. feature 'CLIENT_REGISTRATION_REGION_Омская' (0.0001)
# 697. feature 'VEHICLE_MODEL_Tribeca' (0.0001)
# 698. feature 'POLICY_INTERMEDIARY_370' (0.0001)
# 699. feature 'POLICY_INTERMEDIARY_362' (0.0001)
# 700. feature 'POLICY_INTERMEDIARY_1190' (0.0001)
# 701. feature 'CLAIM_AVG_ACC_ST_PRD_45' (0.0001)
# 702. feature 'CLAIM_AVG_ACC_ST_PRD_3.333333333' (0.0001)
# 703. feature 'CLIENT_REGISTRATION_REGION_Удмуртская' (0.0001)
# 704. feature 'VEHICLE_MODEL_Siber' (0.0001)
# 705. feature 'VEHICLE_MODEL_2' (0.0001)
# 706. feature 'POLICY_INTERMEDIARY_517' (0.0001)
# 707. feature 'VEHICLE_MODEL_Matrix' (0.0001)
# 708. feature 'VEHICLE_MODEL_Grand Starex' (0.0001)
# 709. feature 'CLAIM_AVG_ACC_ST_PRD_67' (0.0001)
# 710. feature 'CLIENT_REGISTRATION_REGION_Вологодская' (0.0001)
# 711. feature 'POLICY_CLM_N_n/d' (0.0001)
# 712. feature 'CLAIM_AVG_ACC_ST_PRD_19.май' (0.0001)
# 713. feature 'POLICY_INTERMEDIARY_1304' (0.0001)
# 714. feature 'POLICY_INTERMEDIARY_786' (0.0001)
# 715. feature 'VEHICLE_MODEL_QX50' (0.0001)
# 716. feature 'CLIENT_REGISTRATION_REGION_Кировская' (0.0001)
# 717. feature 'POLICY_INTERMEDIARY_100' (0.0001)
# 718. feature 'POLICY_INTERMEDIARY_500' (0.0001)
# 719. feature 'POLICY_INTERMEDIARY_1220' (0.0001)
# 720. feature 'VEHICLE_MODEL_Caliber' (0.0001)
# 721. feature 'POLICY_INTERMEDIARY_246' (0.0001)
# 722. feature 'CLAIM_AVG_ACC_ST_PRD_6.333333333' (0.0001)
# 723. feature 'POLICY_INTERMEDIARY_126' (0.0001)
# 724. feature 'CLAIM_AVG_ACC_ST_PRD_0.666666667' (0.0001)
# 725. feature 'VEHICLE_MODEL_2194 Kalina' (0.0001)
# 726. feature 'POLICY_INTERMEDIARY_894' (0.0001)
# 727. feature 'CLAIM_AVG_ACC_ST_PRD_48' (0.0001)
# 728. feature 'POLICY_INTERMEDIARY_1033' (0.0001)
# 729. feature 'CLIENT_REGISTRATION_REGION_Коми' (0.0001)
# 730. feature 'POLICY_CLM_GLT_N_n/d' (0.0001)
# 731. feature 'VEHICLE_MODEL_TT' (0.0001)
# 732. feature 'POLICY_INTERMEDIARY_732' (0.0001)
# 733. feature 'POLICY_INTERMEDIARY_1180' (0.0001)
# 734. feature 'VEHICLE_MODEL_3151' (0.0001)
# 735. feature 'POLICY_INTERMEDIARY_1283' (0.0001)
# 736. feature 'POLICY_INTERMEDIARY_76' (0.0001)
# 737. feature 'POLICY_INTERMEDIARY_1195' (0.0001)
# 738. feature 'POLICY_INTERMEDIARY_31' (0.0001)
# 739. feature 'VEHICLE_MODEL_911' (0.0001)
# 740. feature 'POLICY_INTERMEDIARY_27' (0.0001)
# 741. feature 'VEHICLE_MODEL_Latitude' (0.0001)
# 742. feature 'POLICY_INTERMEDIARY_1299' (0.0001)
# 743. feature 'POLICY_INTERMEDIARY_816' (0.0001)
# 744. feature 'POLICY_INTERMEDIARY_506' (0.0001)
# 745. feature 'POLICY_INTERMEDIARY_827' (0.0001)
# 746. feature 'CLAIM_AVG_ACC_ST_PRD_0.333333333' (0.0001)
# 747. feature 'POLICY_INTERMEDIARY_1001' (0.0001)
# 748. feature 'POLICY_INTERMEDIARY_383' (0.0001)
# 749. feature 'POLICY_INTERMEDIARY_627' (0.0001)
# 750. feature 'POLICY_INTERMEDIARY_1233' (0.0001)
# 751. feature 'POLICY_INTERMEDIARY_1234' (0.0001)
# 752. feature 'VEHICLE_MODEL_V40' (0.0001)
# 753. feature 'CLAIM_AVG_ACC_ST_PRD_1.333333333' (0.0001)
# 754. feature 'POLICY_INTERMEDIARY_811' (0.0001)
# 755. feature 'CLAIM_AVG_ACC_ST_PRD_66' (0.0001)
# 756. feature 'POLICY_INTERMEDIARY_503' (0.0001)
# 757. feature 'POLICY_INTERMEDIARY_1291' (0.0001)
# 758. feature 'VEHICLE_MODEL_Emgrand X7' (0.0001)
# 759. feature 'POLICY_INTERMEDIARY_1307' (0.0001)
# 760. feature 'VEHICLE_MODEL_S' (0.0001)
# 761. feature 'POLICY_INTERMEDIARY_1164' (0.0001)
# 762. feature 'POLICY_INTERMEDIARY_1159' (0.0001)
# 763. feature 'POLICY_INTERMEDIARY_411' (0.0001)
# 764. feature 'POLICY_INTERMEDIARY_118' (0.0001)
# 765. feature 'VEHICLE_MODEL_MK' (0.0001)
# 766. feature 'POLICY_INTERMEDIARY_1059' (0.0001)
# 767. feature 'POLICY_INTERMEDIARY_1178' (0.0001)
# 768. feature 'VEHICLE_MODEL_Yaris' (0.0001)
# 769. feature 'CLAIM_AVG_ACC_ST_PRD_3.666666667' (0.0001)
# 770. feature 'POLICY_INTERMEDIARY_1049' (0.0001)
# 771. feature 'VEHICLE_MODEL_Transporter' (0.0001)
# 772. feature 'POLICY_INTERMEDIARY_54' (0.0001)
# 773. feature 'POLICY_INTERMEDIARY_1398' (0.0001)
# 774. feature 'CLAIM_AVG_ACC_ST_PRD_52' (0.0001)
# 775. feature 'VEHICLE_MODEL_2170 Priora' (0.0001)
# 776. feature 'POLICY_INTERMEDIARY_1185' (0.0001)
# 777. feature 'POLICY_INTERMEDIARY_1349' (0.0001)
# 778. feature 'CLAIM_AVG_ACC_ST_PRD_74' (0.0001)
# 779. feature 'POLICY_INTERMEDIARY_1305' (0.0001)
# 780. feature 'POLICY_INTERMEDIARY_1327' (0.0001)
# 781. feature 'VEHICLE_MODEL_Panamera' (0.0001)
# 782. feature 'POLICY_INTERMEDIARY_1119' (0.0001)
# 783. feature 'POLICY_INTERMEDIARY_101' (0.0001)
# 784. feature 'VEHICLE_MODEL_IndiS' (0.0001)
# 785. feature 'CLAIM_AVG_ACC_ST_PRD_71' (0.0001)
# 786. feature 'VEHICLE_MODEL_FX' (0.0001)
# 787. feature 'POLICY_INTERMEDIARY_1230' (0.0001)
# 788. feature 'POLICY_INTERMEDIARY_1247' (0.0001)
# 789. feature 'POLICY_INTERMEDIARY_270' (0.0001)
# 790. feature 'POLICY_INTERMEDIARY_214' (0.0001)
# 791. feature 'VEHICLE_MODEL_2107' (0.0001)
# 792. feature 'VEHICLE_MODEL_11173 Kalina' (0.0001)
# 793. feature 'POLICY_INTERMEDIARY_1365' (0.0001)
# 794. feature 'CLAIM_AVG_ACC_ST_PRD_47' (0.0001)
# 795. feature 'POLICY_INTERMEDIARY_653' (0.0001)
# 796. feature 'POLICY_INTERMEDIARY_1066' (0.0001)
# 797. feature 'CLAIM_AVG_ACC_ST_PRD_11.66666667' (0.0001)
# 798. feature 'POLICY_INTERMEDIARY_1139' (0.0001)
# 799. feature 'VEHICLE_MODEL_Micra' (0.0001)
# 800. feature 'CLIENT_REGISTRATION_REGION_Марий Эл' (0.0001)
# 801. feature 'POLICY_INTERMEDIARY_1005' (0.0001)
# 802. feature 'POLICY_INTERMEDIARY_87' (0.0001)
# 803. feature 'VEHICLE_MODEL_XF' (0.0001)
# 804. feature 'POLICY_INTERMEDIARY_1021' (0.0001)
# 805. feature 'CLAIM_AVG_ACC_ST_PRD_17.май' (0.0001)
# 806. feature 'POLICY_INTERMEDIARY_530' (0.0001)
# 807. feature 'POLICY_INTERMEDIARY_37' (0.0001)
# 808. feature 'POLICY_INTERMEDIARY_59' (0.0001)
# 809. feature 'POLICY_INTERMEDIARY_146' (0.0001)
# 810. feature 'POLICY_INTERMEDIARY_692' (0.0001)
# 811. feature 'POLICY_INTERMEDIARY_597' (0.0001)
# 812. feature 'VEHICLE_MODEL_Laguna' (0.0001)
# 813. feature 'POLICY_INTERMEDIARY_672' (0.0001)
# 814. feature 'POLICY_INTERMEDIARY_1128' (0.0001)
# 815. feature 'VEHICLE_MODEL_Emgrand EC7' (0.0001)
# 816. feature 'CLAIM_AVG_ACC_ST_PRD_55' (0.0001)
# 817. feature 'POLICY_INTERMEDIARY_643' (0.0001)
# 818. feature 'CLAIM_AVG_ACC_ST_PRD_13.май' (0.0001)
# 819. feature 'VEHICLE_MODEL_Scirocco' (0.0001)
# 820. feature 'POLICY_INTERMEDIARY_446' (0.0001)
# 821. feature 'CLIENT_REGISTRATION_REGION_Ульяновская' (0.0001)
# 822. feature 'POLICY_INTERMEDIARY_840' (0.0001)
# 823. feature 'CLAIM_AVG_ACC_ST_PRD_79' (0.0001)
# 824. feature 'POLICY_INTERMEDIARY_890' (0.0001)
# 825. feature 'POLICY_INTERMEDIARY_1400' (0.0001)
# 826. feature 'CLAIM_AVG_ACC_ST_PRD_22.май' (0.0001)
# 827. feature 'POLICY_INTERMEDIARY_851' (0.0001)
# 828. feature 'POLICY_INTERMEDIARY_1242' (0.0001)
# 829. feature 'POLICY_INTERMEDIARY_1091' (0.0001)
# 830. feature 'POLICY_INTERMEDIARY_529' (0.0001)
# 831. feature 'VEHICLE_MODEL_107' (0.0001)
# 832. feature 'POLICY_INTERMEDIARY_524' (0.0001)
# 833. feature 'CLAIM_AVG_ACC_ST_PRD_16.май' (0.0001)
# 834. feature 'POLICY_INTERMEDIARY_61' (0.0001)
# 835. feature 'POLICY_INTERMEDIARY_495' (0.0001)
# 836. feature 'POLICY_INTERMEDIARY_563' (0.0001)
# 837. feature 'POLICY_INTERMEDIARY_1174' (0.0001)
# 838. feature 'POLICY_INTERMEDIARY_1108' (0.0001)
# 839. feature 'VEHICLE_MODEL_LX' (0.0001)
# 840. feature 'POLICY_INTERMEDIARY_1053' (0.0001)
# 841. feature 'CLAIM_AVG_ACC_ST_PRD_5.666666667' (0.0001)
# 842. feature 'POLICY_INTERMEDIARY_1' (0.0001)
# 843. feature 'POLICY_INTERMEDIARY_1152' (0.0001)
# 844. feature 'VEHICLE_MODEL_CLS' (0.0001)
# 845. feature 'POLICY_INTERMEDIARY_657' (0.0001)
# 846. feature 'POLICY_INTERMEDIARY_710' (0.0001)
# 847. feature 'POLICY_INTERMEDIARY_646' (0.0001)
# 848. feature 'CLAIM_AVG_ACC_ST_PRD_58' (0.0001)
# 849. feature 'CLAIM_AVG_ACC_ST_PRD_59' (0.0001)
# 850. feature 'CLAIM_AVG_ACC_ST_PRD_2.666666667' (0.0001)
# 851. feature 'CLAIM_AVG_ACC_ST_PRD_96' (0.0001)
# 852. feature 'VEHICLE_MODEL_Legacy' (0.0001)
# 853. feature 'POLICY_INTERMEDIARY_696' (0.0001)
# 854. feature 'VEHICLE_MODEL_GX' (0.0001)
# 855. feature 'CLAIM_AVG_ACC_ST_PRD_46' (0.0001)
# 856. feature 'CLAIM_AVG_ACC_ST_PRD_51' (0.0001)
# 857. feature 'CLIENT_REGISTRATION_REGION_Ханты-Мансийский Автономный округ - Югра' (0.0001)
# 858. feature 'POLICY_INTERMEDIARY_1144' (0.0001)
# 859. feature 'VEHICLE_MODEL_1118 Kalina' (0.0001)
# 860. feature 'POLICY_INTERMEDIARY_1186' (0.0001)
# 861. feature 'VEHICLE_MODEL_Vitara' (0.0001)
# 862. feature 'VEHICLE_MODEL_X4' (0.0001)
# 863. feature 'CLAIM_AVG_ACC_ST_PRD_24.май' (0.0001)
# 864. feature 'CLAIM_AVG_ACC_ST_PRD_21.май' (0.0001)
# 865. feature 'POLICY_INTERMEDIARY_58' (0.0001)
# 866. feature 'POLICY_INTERMEDIARY_1081' (0.0001)
# 867. feature 'POLICY_INTERMEDIARY_480' (0.0000)
# 868. feature 'CLIENT_REGISTRATION_REGION_Томская' (0.0000)
# 869. feature 'CLAIM_AVG_ACC_ST_PRD_2.333333333' (0.0000)
# 870. feature 'POLICY_INTERMEDIARY_536' (0.0000)
# 871. feature 'POLICY_INTERMEDIARY_1179' (0.0000)
# 872. feature 'POLICY_INTERMEDIARY_1130' (0.0000)
# 873. feature 'VEHICLE_MODEL_A' (0.0000)
# 874. feature 'CLAIM_AVG_ACC_ST_PRD_78' (0.0000)
# 875. feature 'POLICY_INTERMEDIARY_1045' (0.0000)
# 876. feature 'CLAIM_AVG_ACC_ST_PRD_72' (0.0000)
# 877. feature 'POLICY_INTERMEDIARY_1324' (0.0000)
# 878. feature 'VEHICLE_MODEL_Другая модель (Прицепы к грузовым автомобилям)' (0.0000)
# 879. feature 'CLAIM_AVG_ACC_ST_PRD_4.666666667' (0.0000)
# 880. feature 'VEHICLE_MODEL_Wrangler' (0.0000)
# 881. feature 'POLICY_INTERMEDIARY_654' (0.0000)
# 882. feature 'POLICY_INTERMEDIARY_1360' (0.0000)
# 883. feature 'POLICY_INTERMEDIARY_572' (0.0000)
# 884. feature 'VEHICLE_MODEL_23632' (0.0000)
# 885. feature 'CLAIM_AVG_ACC_ST_PRD_53' (0.0000)
# 886. feature 'POLICY_INTERMEDIARY_1080' (0.0000)
# 887. feature 'VEHICLE_MODEL_CX-9' (0.0000)
# 888. feature 'VEHICLE_MODEL_Escalade' (0.0000)
# 889. feature 'CLAIM_AVG_ACC_ST_PRD_4.333333333' (0.0000)
# 890. feature 'POLICY_INTERMEDIARY_772' (0.0000)
# 891. feature 'POLICY_INTERMEDIARY_5' (0.0000)
# 892. feature 'VEHICLE_MODEL_Splash' (0.0000)
# 893. feature 'VEHICLE_MODEL_Другая модель (Автобус)' (0.0000)
# 894. feature 'POLICY_INTERMEDIARY_1032' (0.0000)
# 895. feature 'POLICY_INTERMEDIARY_830' (0.0000)
# 896. feature 'POLICY_INTERMEDIARY_1013' (0.0000)
# 897. feature 'VEHICLE_MODEL_SL' (0.0000)
# 898. feature 'VEHICLE_MODEL_XJ' (0.0000)
# 899. feature 'POLICY_INTERMEDIARY_473' (0.0000)
# 900. feature 'POLICY_INTERMEDIARY_13' (0.0000)
# 901. feature 'POLICY_INTERMEDIARY_1036' (0.0000)
# 902. feature 'POLICY_INTERMEDIARY_537' (0.0000)
# 903. feature 'VEHICLE_MODEL_Alhambra' (0.0000)
# 904. feature 'VEHICLE_MODEL_Tourneo Connect' (0.0000)
# 905. feature 'VEHICLE_MODEL_Cobalt' (0.0000)
# 906. feature 'POLICY_INTERMEDIARY_554' (0.0000)
# 907. feature 'VEHICLE_MODEL_Cooper' (0.0000)
# 908. feature 'VEHICLE_MODEL_RS Q3' (0.0000)
# 909. feature 'VEHICLE_MODEL_Escape' (0.0000)
# 910. feature 'POLICY_INTERMEDIARY_8' (0.0000)
# 911. feature 'VEHICLE_MODEL_CLA' (0.0000)
# 912. feature 'VEHICLE_MODEL_Multivan' (0.0000)
# 913. feature 'CLIENT_REGISTRATION_REGION_Алтайский' (0.0000)
# 914. feature 'VEHICLE_MODEL_New Beetle' (0.0000)
# 915. feature 'POLICY_INTERMEDIARY_625' (0.0000)
# 916. feature 'CLIENT_REGISTRATION_REGION_Оренбургская' (0.0000)
# 917. feature 'POLICY_INTERMEDIARY_691' (0.0000)
# 918. feature 'POLICY_INTERMEDIARY_601' (0.0000)
# 919. feature 'CLAIM_AVG_ACC_ST_PRD_27.май' (0.0000)
# 920. feature 'VEHICLE_MODEL_2105' (0.0000)
# 921. feature 'POLICY_INTERMEDIARY_104' (0.0000)
# 922. feature 'POLICY_INTERMEDIARY_902' (0.0000)
# 923. feature 'POLICY_INTERMEDIARY_642' (0.0000)
# 924. feature 'CLAIM_AVG_ACC_ST_PRD_65' (0.0000)
# 925. feature 'CLAIM_AVG_ACC_ST_PRD_12.33333333' (0.0000)
# 926. feature 'VEHICLE_MODEL_Kizashi' (0.0000)
# 927. feature 'POLICY_INTERMEDIARY_737' (0.0000)
# 928. feature 'POLICY_INTERMEDIARY_1074' (0.0000)
# 929. feature 'POLICY_INTERMEDIARY_405' (0.0000)
# 930. feature 'POLICY_INTERMEDIARY_644' (0.0000)
# 931. feature 'POLICY_INTERMEDIARY_656' (0.0000)
# 932. feature 'CLAIM_AVG_ACC_ST_PRD_70' (0.0000)
# 933. feature 'POLICY_INTERMEDIARY_175' (0.0000)
# 934. feature 'VEHICLE_MODEL_217230 Priora' (0.0000)
# 935. feature 'POLICY_INTERMEDIARY_1015' (0.0000)
# 936. feature 'POLICY_INTERMEDIARY_673' (0.0000)
# 937. feature 'POLICY_INTERMEDIARY_1069' (0.0000)
# 938. feature 'POLICY_INTERMEDIARY_1300' (0.0000)
# 939. feature 'POLICY_INTERMEDIARY_53' (0.0000)
# 940. feature 'POLICY_INTERMEDIARY_872' (0.0000)
# 941. feature 'POLICY_INTERMEDIARY_743' (0.0000)
# 942. feature 'POLICY_INTERMEDIARY_1009' (0.0000)
# 943. feature 'POLICY_INTERMEDIARY_1332' (0.0000)
# 944. feature 'VEHICLE_MODEL_2-series' (0.0000)
# 945. feature 'CLAIM_AVG_ACC_ST_PRD_89' (0.0000)
# 946. feature 'POLICY_INTERMEDIARY_1390' (0.0000)
# 947. feature 'POLICY_INTERMEDIARY_488' (0.0000)
# 948. feature 'CLIENT_REGISTRATION_REGION_Пермский' (0.0000)
# 949. feature 'VEHICLE_MODEL_X6 M' (0.0000)
# 950. feature 'POLICY_INTERMEDIARY_1042' (0.0000)
# 951. feature 'POLICY_INTERMEDIARY_128' (0.0000)
# 952. feature 'POLICY_INTERMEDIARY_1115' (0.0000)
# 953. feature 'POLICY_INTERMEDIARY_1197' (0.0000)
# 954. feature 'POLICY_INTERMEDIARY_765' (0.0000)
# 955. feature 'POLICY_INTERMEDIARY_231' (0.0000)
# 956. feature 'POLICY_INTERMEDIARY_131' (0.0000)
# 957. feature 'POLICY_INTERMEDIARY_341' (0.0000)
# 958. feature 'POLICY_INTERMEDIARY_1212' (0.0000)
# 959. feature 'POLICY_INTERMEDIARY_671' (0.0000)
# 960. feature 'POLICY_INTERMEDIARY_1171' (0.0000)
# 961. feature 'POLICY_INTERMEDIARY_1148' (0.0000)
# 962. feature 'POLICY_INTERMEDIARY_805' (0.0000)
# 963. feature 'POLICY_INTERMEDIARY_608' (0.0000)
# 964. feature 'POLICY_INTERMEDIARY_1342' (0.0000)
# 965. feature 'POLICY_INTERMEDIARY_668' (0.0000)
# 966. feature 'POLICY_INTERMEDIARY_817' (0.0000)
# 967. feature 'POLICY_INTERMEDIARY_107' (0.0000)
# 968. feature 'VEHICLE_MODEL_GS' (0.0000)
# 969. feature 'POLICY_INTERMEDIARY_347' (0.0000)
# 970. feature 'VEHICLE_MODEL_X5 M' (0.0000)
# 971. feature 'POLICY_INTERMEDIARY_1169' (0.0000)
# 972. feature 'POLICY_INTERMEDIARY_1236' (0.0000)
# 973. feature 'VEHICLE_MODEL_S80' (0.0000)
# 974. feature 'POLICY_INTERMEDIARY_1249' (0.0000)
# 975. feature 'POLICY_INTERMEDIARY_940' (0.0000)
# 976. feature 'POLICY_INTERMEDIARY_1145' (0.0000)
# 977. feature 'VEHICLE_MODEL_5' (0.0000)
# 978. feature 'POLICY_INTERMEDIARY_102' (0.0000)
# 979. feature 'POLICY_INTERMEDIARY_172' (0.0000)
# 980. feature 'POLICY_INTERMEDIARY_161' (0.0000)
# 981. feature 'VEHICLE_MODEL_Grandis' (0.0000)
# 982. feature 'VEHICLE_MODEL_Panda' (0.0000)
# 983. feature 'CLIENT_REGISTRATION_REGION_Сахалинская' (0.0000)
# 984. feature 'POLICY_INTERMEDIARY_40' (0.0000)
# 985. feature 'POLICY_INTERMEDIARY_582' (0.0000)
# 986. feature 'POLICY_INTERMEDIARY_1361' (0.0000)
# 987. feature 'POLICY_INTERMEDIARY_91' (0.0000)
# 988. feature 'CLAIM_AVG_ACC_ST_PRD_102' (0.0000)
# 989. feature 'CLAIM_AVG_ACC_ST_PRD_31.май' (0.0000)
# 990. feature 'POLICY_INTERMEDIARY_594' (0.0000)
# 991. feature 'VEHICLE_MODEL_Spectra' (0.0000)
# 992. feature 'POLICY_INTERMEDIARY_867' (0.0000)
# 993. feature 'POLICY_INTERMEDIARY_1072' (0.0000)
# 994. feature 'POLICY_INTERMEDIARY_355' (0.0000)
# 995. feature 'VEHICLE_MODEL_Terrano' (0.0000)
# 996. feature 'CLAIM_AVG_ACC_ST_PRD_20.май' (0.0000)
# 997. feature 'VEHICLE_MAKE_Brilliance' (0.0000)
# 998. feature 'POLICY_INTERMEDIARY_1382' (0.0000)
# 999. feature 'POLICY_INTERMEDIARY_1394' (0.0000)
# 1000. feature 'VEHICLE_MODEL_Grandeur' (0.0000)
# ...
# 2388. feature 'CLAIM_AVG_ACC_ST_PRD_193' (0.0000)
# 2389. feature 'VEHICLE_MODEL_Tiggo 5' (0.0000)
# 2390. feature 'VEHICLE_MODEL_Grand Caravan' (0.0000)
# 2391. feature 'CLAIM_AVG_ACC_ST_PRD_41.66666667' (0.0000)
# 2392. feature 'POLICY_INTERMEDIARY_591' (0.0000)
# 2393. feature 'POLICY_INTERMEDIARY_1175' (0.0000)
# 2394. feature 'POLICY_INTERMEDIARY_136' (0.0000)
# 2395. feature 'POLICY_INTERMEDIARY_23' (0.0000)
# 2396. feature 'CLAIM_AVG_ACC_ST_PRD_12.июн' (0.0000)
# 2397. feature 'POLICY_INTERMEDIARY_334' (0.0000)
# 2398. feature 'POLICY_INTERMEDIARY_413' (0.0000)
# 2399. feature 'POLICY_INTERMEDIARY_1387' (0.0000)
# 2400. feature 'POLICY_INTERMEDIARY_1014' (0.0000)
# 2401. feature 'POLICY_INTERMEDIARY_1385' (0.0000)
# 2402. feature 'CLAIM_AVG_ACC_ST_PRD_26.фев' (0.0000)
# 2403. feature 'CLAIM_AVG_ACC_ST_PRD_136.5' (0.0000)
# 2404. feature 'POLICY_INTERMEDIARY_796' (0.0000)
# 2405. feature 'POLICY_INTERMEDIARY_1046' (0.0000)
# 2406. feature 'POLICY_INTERMEDIARY_470' (0.0000)
# 2407. feature 'CLAIM_AVG_ACC_ST_PRD_61.5' (0.0000)
# 2408. feature 'POLICY_INTERMEDIARY_711' (0.0000)
# 2409. feature 'POLICY_INTERMEDIARY_922' (0.0000)
# 2410. feature 'VEHICLE_MODEL_217210 Priora' (0.0000)
# 2411. feature 'CLAIM_AVG_ACC_ST_PRD_116' (0.0000)
# 2412. feature 'VEHICLE_MAKE_Hafei' (0.0000)
# 2413. feature 'POLICY_INTERMEDIARY_283' (0.0000)
# 2414. feature 'CLAIM_AVG_ACC_ST_PRD_297' (0.0000)
# 2415. feature 'CLAIM_AVG_ACC_ST_PRD_27.16666667' (0.0000)
# 2416. feature 'POLICY_INTERMEDIARY_484' (0.0000)
# 2417. feature 'POLICY_INTERMEDIARY_905' (0.0000)
# 2418. feature 'VEHICLE_MODEL_Vision' (0.0000)
# 2419. feature 'CLAIM_AVG_ACC_ST_PRD_3.166666667' (0.0000)
# 2420. feature 'CLAIM_AVG_ACC_ST_PRD_45.66666667' (0.0000)
# 2421. feature 'VEHICLE_MODEL_Carrera' (0.0000)
# 2422. feature 'POLICY_INTERMEDIARY_1177' (0.0000)
# 2423. feature 'CLAIM_AVG_ACC_ST_PRD_101.5' (0.0000)
# 2424. feature 'POLICY_INTERMEDIARY_113' (0.0000)
# 2425. feature 'CLAIM_AVG_ACC_ST_PRD_245' (0.0000)
# 2426. feature 'POLICY_INTERMEDIARY_812' (0.0000)
# 2427. feature 'CLAIM_AVG_ACC_ST_PRD_18.25' (0.0000)
# 2428. feature 'POLICY_INTERMEDIARY_32' (0.0000)
# 2429. feature 'CLAIM_AVG_ACC_ST_PRD_80.33333333' (0.0000)
# 2430. feature 'CLAIM_AVG_ACC_ST_PRD_116.5' (0.0000)
# 2431. feature 'POLICY_INTERMEDIARY_263' (0.0000)
# 2432. feature 'POLICY_INTERMEDIARY_1294' (0.0000)
# 2433. feature 'POLICY_INTERMEDIARY_897' (0.0000)
# 2434. feature 'POLICY_INTERMEDIARY_11' (0.0000)
# 2435. feature 'POLICY_INTERMEDIARY_858' (0.0000)
# 2436. feature 'CLAIM_AVG_ACC_ST_PRD_126' (0.0000)
# 2437. feature 'POLICY_INTERMEDIARY_1282' (0.0000)
# 2438. feature 'POLICY_INTERMEDIARY_1375' (0.0000)
# 2439. feature 'CLAIM_AVG_ACC_ST_PRD_мар.25' (0.0000)
# 2440. feature 'CLAIM_AVG_ACC_ST_PRD_дек.75' (0.0000)
# 2441. feature 'POLICY_INTERMEDIARY_1077' (0.0000)
# 2442. feature 'CLAIM_AVG_ACC_ST_PRD_159.5' (0.0000)
# 2443. feature 'POLICY_INTERMEDIARY_599' (0.0000)
# 2444. feature 'POLICY_INTERMEDIARY_662' (0.0000)
# 2445. feature 'POLICY_INTERMEDIARY_1099' (0.0000)
# 2446. feature 'CLAIM_AVG_ACC_ST_PRD_19.33333333' (0.0000)
# 2447. feature 'VEHICLE_MODEL_Impreza WRX STI' (0.0000)
# 2448. feature 'POLICY_INTERMEDIARY_325' (0.0000)
# 2449. feature 'POLICY_INTERMEDIARY_195' (0.0000)
# 2450. feature 'POLICY_INTERMEDIARY_268' (0.0000)
# 2451. feature 'CLAIM_AVG_ACC_ST_PRD_13.июн' (0.0000)
# 2452. feature 'POLICY_INTERMEDIARY_1298' (0.0000)
# 2453. feature 'CLAIM_AVG_ACC_ST_PRD_128.5' (0.0000)
# 2454. feature 'POLICY_INTERMEDIARY_581' (0.0000)
# 2455. feature 'POLICY_INTERMEDIARY_607' (0.0000)
# 2456. feature 'VEHICLE_MODEL_Avalon' (0.0000)
# 2457. feature 'POLICY_INTERMEDIARY_233' (0.0000)
# 2458. feature 'VEHICLE_MODEL_Voyager' (0.0000)
# 2459. feature 'CLAIM_AVG_ACC_ST_PRD_191' (0.0000)
# 2460. feature 'POLICY_INTERMEDIARY_934' (0.0000)
# 2461. feature 'CLAIM_AVG_ACC_ST_PRD_14.83333333' (0.0000)
# 2462. feature 'POLICY_INTERMEDIARY_1259' (0.0000)
# 2463. feature 'POLICY_INTERMEDIARY_1359' (0.0000)
# 2464. feature 'POLICY_INTERMEDIARY_623' (0.0000)
# 2465. feature 'CLAIM_AVG_ACC_ST_PRD_326' (0.0000)
# 2466. feature 'POLICY_INTERMEDIARY_610' (0.0000)
# 2467. feature 'POLICY_INTERMEDIARY_604' (0.0000)
# 2468. feature 'POLICY_INTERMEDIARY_1256' (0.0000)
# 2469. feature 'POLICY_INTERMEDIARY_1336' (0.0000)
# 2470. feature 'CLAIM_AVG_ACC_ST_PRD_241' (0.0000)
# 2471. feature 'VEHICLE_MODEL_2109' (0.0000)
# 2472. feature 'CLAIM_AVG_ACC_ST_PRD_13.14285714' (0.0000)
# 2473. feature 'CLAIM_AVG_ACC_ST_PRD_127.5' (0.0000)
# 2474. feature 'POLICY_INTERMEDIARY_1350' (0.0000)
# 2475. feature 'CLAIM_AVG_ACC_ST_PRD_32.75' (0.0000)
# 2476. feature 'POLICY_INTERMEDIARY_1226' (0.0000)
# 2477. feature 'POLICY_INTERMEDIARY_227' (0.0000)
# 2478. feature 'POLICY_INTERMEDIARY_1229' (0.0000)
# 2479. feature 'VEHICLE_MODEL_2194 Kalina Cross' (0.0000)
# 2480. feature 'POLICY_INTERMEDIARY_123' (0.0000)
# 2481. feature 'CLAIM_AVG_ACC_ST_PRD_321' (0.0000)
# 2482. feature 'POLICY_INTERMEDIARY_223' (0.0000)
# 2483. feature 'POLICY_INTERMEDIARY_1237' (0.0000)
# 2484. feature 'POLICY_INTERMEDIARY_216' (0.0000)
# 2485. feature 'POLICY_INTERMEDIARY_212' (0.0000)
# 2486. feature 'POLICY_INTERMEDIARY_747' (0.0000)
# 2487. feature 'POLICY_INTERMEDIARY_21' (0.0000)
# 2488. feature 'POLICY_INTERMEDIARY_1243' (0.0000)
# 2489. feature 'POLICY_INTERMEDIARY_1354' (0.0000)
# 2490. feature 'CLAIM_AVG_ACC_ST_PRD_120' (0.0000)
# 2491. feature 'POLICY_INTERMEDIARY_209' (0.0000)
# 2492. feature 'POLICY_INTERMEDIARY_206' (0.0000)
# 2493. feature 'CLAIM_AVG_ACC_ST_PRD_122.5' (0.0000)
# 2494. feature 'CLAIM_AVG_ACC_ST_PRD_33.33333333' (0.0000)
# 2495. feature 'CLAIM_AVG_ACC_ST_PRD_125' (0.0000)
# 2496. feature 'POLICY_INTERMEDIARY_744' (0.0000)
# 2497. feature 'POLICY_INTERMEDIARY_687' (0.0000)
# 2498. feature 'VEHICLE_MODEL_208' (0.0000)
# 2499. feature 'CLAIM_AVG_ACC_ST_PRD_186' (0.0000)
# 2500. feature 'CLAIM_AVG_ACC_ST_PRD_354' (0.0000)
# 2501. feature 'CLAIM_AVG_ACC_ST_PRD_61.66666667' (0.0000)
# 2502. feature 'POLICY_INTERMEDIARY_1309' (0.0000)
# 2503. feature 'POLICY_INTERMEDIARY_151' (0.0000)
# 2504. feature 'POLICY_INTERMEDIARY_150' (0.0000)
# 2505. feature 'POLICY_INTERMEDIARY_651' (0.0000)
# 2506. feature 'CLAIM_AVG_ACC_ST_PRD_15.авг' (0.0000)
# 2507. feature 'POLICY_INTERMEDIARY_130' (0.0000)
# 2508. feature 'POLICY_INTERMEDIARY_659' (0.0000)
# 2509. feature 'CLAIM_AVG_ACC_ST_PRD_152.5' (0.0000)
# 2510. feature 'POLICY_INTERMEDIARY_676' (0.0000)
# 2511. feature 'CLAIM_AVG_ACC_ST_PRD_345' (0.0000)
# 2512. feature 'CLAIM_AVG_ACC_ST_PRD_153' (0.0000)
# 2513. feature 'CLAIM_AVG_ACC_ST_PRD_155' (0.0000)
# 2514. feature 'VEHICLE_MAKE_Jcb' (0.0000)
# 2515. feature 'CLAIM_AVG_ACC_ST_PRD_35.33333333' (0.0000)
# 2516. feature 'CLAIM_AVG_ACC_ST_PRD_561' (0.0000)
# 2517. feature 'VEHICLE_MAKE_ПАЗ' (0.0000)
# 2518. feature 'CLAIM_AVG_ACC_ST_PRD_176.5' (0.0000)
# 2519. feature 'CLIENT_REGISTRATION_REGION_Ненецкий' (0.0000)
# 2520. feature 'POLICY_INTERMEDIARY_71' (0.0000)
# 2521. feature 'POLICY_INTERMEDIARY_666' (0.0000)
# 2522. feature 'CLAIM_AVG_ACC_ST_PRD_16.фев' (0.0000)
# 2523. feature 'POLICY_INTERMEDIARY_1388' (0.0000)
# 2524. feature 'CLAIM_AVG_ACC_ST_PRD_176' (0.0000)
# 2525. feature 'POLICY_INTERMEDIARY_1317' (0.0000)
# 2526. feature 'CLAIM_AVG_ACC_ST_PRD_37.33333333' (0.0000)
# 2527. feature 'CLAIM_AVG_ACC_ST_PRD_57.25' (0.0000)
# 2528. feature 'VEHICLE_MAKE_Changan' (0.0000)
# 2529. feature 'CLAIM_AVG_ACC_ST_PRD_240' (0.0000)
# 2530. feature 'VEHICLE_MODEL_Sedici' (0.0000)
# 2531. feature 'CLAIM_AVG_ACC_ST_PRD_15.75' (0.0000)
# 2532. feature 'VEHICLE_MODEL_RCZ' (0.0000)
# 2533. feature 'CLAIM_AVG_ACC_ST_PRD_58.5' (0.0000)
# 2534. feature 'POLICY_INTERMEDIARY_65' (0.0000)
# 2535. feature 'POLICY_INTERMEDIARY_631' (0.0000)
# 2536. feature 'POLICY_INTERMEDIARY_179' (0.0000)
# 2537. feature 'CLAIM_AVG_ACC_ST_PRD_185.5' (0.0000)
# 2538. feature 'POLICY_INTERMEDIARY_632' (0.0000)
# 2539. feature 'POLICY_INTERMEDIARY_1279' (0.0000)
# 2540. feature 'POLICY_INTERMEDIARY_169' (0.0000)
# 2541. feature 'CLAIM_AVG_ACC_ST_PRD_365' (0.0000)
# 2542. feature 'CLAIM_AVG_ACC_ST_PRD_14.25' (0.0000)
# 2543. feature 'CLAIM_AVG_ACC_ST_PRD_353.5' (0.0000)
# 2544. feature 'VEHICLE_MODEL_Tager' (0.0000)
# 2545. feature 'CLAIM_AVG_ACC_ST_PRD_35.75' (0.0000)
# 2546. feature 'POLICY_INTERMEDIARY_729' (0.0000)
# 2547. feature 'CLAIM_AVG_ACC_ST_PRD_38.66666667' (0.0000)
# 2548. feature 'CLAIM_AVG_ACC_ST_PRD_181.5' (0.0000)
# 2549. feature 'CLAIM_AVG_ACC_ST_PRD_141' (0.0000)
# 2550. feature 'CLAIM_AVG_ACC_ST_PRD_25.57142857' (0.0000)
# 2551. feature 'CLAIM_AVG_ACC_ST_PRD_58.75' (0.0000)
# 2552. feature 'CLAIM_AVG_ACC_ST_PRD_143' (0.0000)
# 2553. feature 'CLAIM_AVG_ACC_ST_PRD_143.3333333' (0.0000)
# 2554. feature 'POLICY_INTERMEDIARY_162' (0.0000)
# 2555. feature 'CLAIM_AVG_ACC_ST_PRD_338' (0.0000)
# 2556. feature 'VEHICLE_MAKE_Rolls-Royce' (0.0000)
# 2557. feature 'VEHICLE_MAKE_<Пусто>' (0.0000)
# 2558. feature 'CLAIM_AVG_ACC_ST_PRD_146.5' (0.0000)
# 2559. feature 'POLICY_INTERMEDIARY_726' (0.0000)
# 2560. feature 'CLAIM_AVG_ACC_ST_PRD_148.5' (0.0000)
# 2561. feature 'CLAIM_AVG_ACC_ST_PRD_56.33333333' (0.0000)
# 2562. feature 'POLICY_INTERMEDIARY_752' (0.0000)
# 2563. feature 'POLICY_INTERMEDIARY_876' (0.0000)
# 2564. feature 'VEHICLE_MODEL_301' (0.0000)
# 2565. feature 'CLAIM_AVG_ACC_ST_PRD_230' (0.0000)
# 2566. feature 'POLICY_INTERMEDIARY_957' (0.0000)
# 2567. feature 'CLAIM_AVG_ACC_ST_PRD_23.33333333' (0.0000)
# 2568. feature 'POLICY_INTERMEDIARY_945' (0.0000)
# 2569. feature 'POLICY_INTERMEDIARY_111' (0.0000)
# 2570. feature 'CLAIM_AVG_ACC_ST_PRD_268' (0.0000)
# 2571. feature 'POLICY_INTERMEDIARY_941' (0.0000)
# 2572. feature 'POLICY_INTERMEDIARY_351' (0.0000)
# 2573. feature 'POLICY_INTERMEDIARY_959' (0.0000)
# 2574. feature 'CLAIM_AVG_ACC_ST_PRD_283' (0.0000)
# 2575. feature 'VEHICLE_MODEL_Eos' (0.0000)
# 2576. feature 'POLICY_INTERMEDIARY_932' (0.0000)
# 2577. feature 'CLAIM_AVG_ACC_ST_PRD_71.5' (0.0000)
# 2578. feature 'POLICY_INTERMEDIARY_930' (0.0000)
# 2579. feature 'POLICY_INTERMEDIARY_93' (0.0000)
# 2580. feature 'VEHICLE_MODEL_Discovery Sport' (0.0000)
# 2581. feature 'POLICY_INTERMEDIARY_349' (0.0000)
# 2582. feature 'POLICY_INTERMEDIARY_1104' (0.0000)
# 2583. feature 'CLAIM_AVG_ACC_ST_PRD_47.33333333' (0.0000)
# 2584. feature 'CLAIM_AVG_ACC_ST_PRD_290' (0.0000)
# 2585. feature 'POLICY_INTERMEDIARY_813' (0.0000)
# 2586. feature 'POLICY_INTERMEDIARY_514' (0.0000)
# 2587. feature 'POLICY_INTERMEDIARY_1129' (0.0000)
# 2588. feature 'CLAIM_AVG_ACC_ST_PRD_260' (0.0000)
# 2589. feature 'POLICY_INTERMEDIARY_112' (0.0000)
# 2590. feature 'POLICY_INTERMEDIARY_975' (0.0000)
# 2591. feature 'POLICY_INTERMEDIARY_964' (0.0000)
# 2592. feature 'POLICY_INTERMEDIARY_821' (0.0000)
# 2593. feature 'CLAIM_AVG_ACC_ST_PRD_262' (0.0000)
# 2594. feature 'VEHICLE_MODEL_Croma' (0.0000)
# 2595. feature 'POLICY_INTERMEDIARY_822' (0.0000)
# 2596. feature 'CLAIM_AVG_ACC_ST_PRD_286' (0.0000)
# 2597. feature 'POLICY_INTERMEDIARY_828' (0.0000)
# 2598. feature 'POLICY_INTERMEDIARY_356' (0.0000)
# 2599. feature 'POLICY_INTERMEDIARY_836' (0.0000)
# 2600. feature 'CLAIM_AVG_ACC_ST_PRD_197' (0.0000)
# 2601. feature 'POLICY_INTERMEDIARY_893' (0.0000)
# 2602. feature 'POLICY_INTERMEDIARY_453' (0.0000)
# 2603. feature 'CLAIM_AVG_ACC_ST_PRD_78.66666667' (0.0000)
# 2604. feature 'POLICY_INTERMEDIARY_451' (0.0000)
# 2605. feature 'POLICY_INTERMEDIARY_445' (0.0000)
# 2606. feature 'POLICY_INTERMEDIARY_898' (0.0000)
# 2607. feature 'POLICY_INTERMEDIARY_871' (0.0000)
# 2608. feature 'POLICY_INTERMEDIARY_410' (0.0000)
# 2609. feature 'POLICY_INTERMEDIARY_901' (0.0000)
# 2610. feature 'CLAIM_AVG_ACC_ST_PRD_74.66666667' (0.0000)
# 2611. feature 'POLICY_INTERMEDIARY_415' (0.0000)
# 2612. feature 'VEHICLE_MODEL_HR-V' (0.0000)
# 2613. feature 'VEHICLE_MODEL_Hiace' (0.0000)
# 2614. feature 'POLICY_INTERMEDIARY_1050' (0.0000)
# 2615. feature 'POLICY_INTERMEDIARY_878' (0.0000)
# 2616. feature 'POLICY_INTERMEDIARY_864' (0.0000)
# 2617. feature 'POLICY_INTERMEDIARY_402' (0.0000)
# 2618. feature 'POLICY_INTERMEDIARY_928' (0.0000)
# 2619. feature 'CLAIM_AVG_ACC_ST_PRD_28.25' (0.0000)
# 2620. feature 'VEHICLE_MODEL_Lancer Evolution' (0.0000)
# 2621. feature 'POLICY_INTERMEDIARY_367' (0.0000)
# 2622. feature 'POLICY_INTERMEDIARY_1093' (0.0000)
# 2623. feature 'POLICY_INTERMEDIARY_374' (0.0000)
# 2624. feature 'POLICY_INTERMEDIARY_1012' (0.0000)
# 2625. feature 'POLICY_INTERMEDIARY_92' (0.0000)
# 2626. feature 'POLICY_INTERMEDIARY_386' (0.0000)
# 2627. feature 'POLICY_INTERMEDIARY_465' (0.0000)
# 2628. feature 'POLICY_INTERMEDIARY_84' (0.0000)
# 2629. feature 'POLICY_INTERMEDIARY_389' (0.0000)
# 2630. feature 'CLAIM_AVG_ACC_ST_PRD_27.33333333' (0.0000)
# 2631. feature 'POLICY_INTERMEDIARY_1076' (0.0000)
# 2632. feature 'POLICY_INTERMEDIARY_467' (0.0000)
# 2633. feature 'CLAIM_AVG_ACC_ST_PRD_278' (0.0000)
# 2634. feature 'POLICY_INTERMEDIARY_1134' (0.0000)
# 2635. feature 'POLICY_INTERMEDIARY_68' (0.0000)
# 2636. feature 'POLICY_INTERMEDIARY_1136' (0.0000)
# 2637. feature 'CLAIM_AVG_ACC_ST_PRD_06.июн' (0.0000)
# 2638. feature 'POLICY_INTERMEDIARY_12' (0.0000)
# 2639. feature 'CLAIM_AVG_ACC_ST_PRD_52.2' (0.0000)
# 2640. feature 'POLICY_INTERMEDIARY_1198' (0.0000)
# 2641. feature 'POLICY_INTERMEDIARY_259' (0.0000)
# 2642. feature 'VEHICLE_MODEL_Ignis' (0.0000)
# 2643. feature 'POLICY_INTERMEDIARY_775' (0.0000)
# 2644. feature 'CLAIM_AVG_ACC_ST_PRD_67.5' (0.0000)
# 2645. feature 'VEHICLE_MODEL_<Пусто>' (0.0000)
# 2646. feature 'CLAIM_AVG_ACC_ST_PRD_20.33333333' (0.0000)
# 2647. feature 'CLAIM_AVG_ACC_ST_PRD_04.июн' (0.0000)
# 2648. feature 'CLAIM_AVG_ACC_ST_PRD_04.авг' (0.0000)
# 2649. feature 'CLAIM_AVG_ACC_ST_PRD_02.фев' (0.0000)
# 2650. feature 'CLAIM_AVG_ACC_ST_PRD_20.июн' (0.0000)
# 2651. feature 'CLAIM_AVG_ACC_ST_PRD_67.75' (0.0000)
# 2652. feature 'POLICY_INTERMEDIARY_1203' (0.0000)
# 2653. feature 'CLAIM_AVG_ACC_ST_PRD_250' (0.0000)
# 2654. feature 'CLAIM_AVG_ACC_ST_PRD_293' (0.0000)
# 2655. feature 'POLICY_INTERMEDIARY_589' (0.0000)
# 2656. feature 'CLAIM_AVG_ACC_ST_PRD_32.33333333' (0.0000)
# 2657. feature 'VEHICLE_MODEL_Phantom' (0.0000)
# 2658. feature 'POLICY_INTERMEDIARY_595' (0.0000)
# 2659. feature 'CLAIM_AVG_ACC_ST_PRD_313' (0.0000)
# 2660. feature 'POLICY_INTERMEDIARY_1210' (0.0000)
# 2661. feature 'POLICY_INTERMEDIARY_764' (0.0000)
# 2662. feature 'VEHICLE_MODEL_V50' (0.0000)
# 2663. feature 'POLICY_INTERMEDIARY_1204' (0.0000)
# 2664. feature 'CLAIM_AVG_ACC_ST_PRD_103.5' (0.0000)
# 2665. feature 'CLAIM_AVG_ACC_ST_PRD_102.5' (0.0000)
# 2666. feature 'CLAIM_AVG_ACC_ST_PRD_100.5' (0.0000)
# 2667. feature 'POLICY_INTERMEDIARY_1207' (0.0000)
# 2668. feature 'CLAIM_AVG_ACC_ST_PRD_25.фев' (0.0000)
# 2669. feature 'POLICY_INTERMEDIARY_77' (0.0000)
# 2670. feature 'POLICY_INTERMEDIARY_269' (0.0000)
# 2671. feature 'VEHICLE_MODEL_Armada' (0.0000)
# 2672. feature 'POLICY_INTERMEDIARY_558' (0.0000)
# 2673. feature 'CLAIM_AVG_ACC_ST_PRD_222' (0.0000)
# 2674. feature 'POLICY_INTERMEDIARY_298' (0.0000)
# 2675. feature 'CLAIM_AVG_ACC_ST_PRD_212' (0.0000)
# 2676. feature 'POLICY_INTERMEDIARY_302' (0.0000)
# 2677. feature 'POLICY_INTERMEDIARY_798' (0.0000)
# 2678. feature 'POLICY_INTERMEDIARY_318' (0.0000)
# 2679. feature 'CLAIM_AVG_ACC_ST_PRD_298' (0.0000)
# 2680. feature 'POLICY_INTERMEDIARY_527' (0.0000)
# 2681. feature 'CLAIM_AVG_ACC_ST_PRD_305' (0.0000)
# 2682. feature 'POLICY_INTERMEDIARY_324' (0.0000)
# 2683. feature 'VEHICLE_MODEL_Caravan' (0.0000)
# 2684. feature 'POLICY_INTERMEDIARY_520' (0.0000)
# 2685. feature 'POLICY_INTERMEDIARY_999' (0.0000)
# 2686. feature 'POLICY_INTERMEDIARY_997' (0.0000)
# 2687. feature 'POLICY_INTERMEDIARY_996' (0.0000)
# 2688. feature 'CLAIM_AVG_ACC_ST_PRD_95.66666667' (0.0000)
# 2689. feature 'CLAIM_AVG_ACC_ST_PRD_3.888888889' (0.0000)
# 2690. feature 'CLAIM_AVG_ACC_ST_PRD_30.33333333' (0.0000)
# 2691. feature 'POLICY_INTERMEDIARY_29' (0.0000)
# 2692. feature 'CLAIM_AVG_ACC_ST_PRD_0.4' (0.0000)
# 2693. feature 'VEHICLE_MODEL_C-Elysee' (0.0000)
# 2694. feature 'CLAIM_AVG_ACC_ST_PRD_0.428571429' (0.0000)
# 2695. feature 'CLAIM_AVG_ACC_ST_PRD_69.66666667' (0.0000)
# 2696. feature 'CLAIM_AVG_ACC_ST_PRD_200' (0.0000)
# 2697. feature 'VEHICLE_MODEL_Bravo' (0.0000)
# 2698. feature 'POLICY_INTERMEDIARY_791' (0.0000)
# 2699. feature 'POLICY_INTERMEDIARY_790' (0.0000)
# 2700. feature 'POLICY_INTERMEDIARY_548' (0.0000)
# 2701. feature 'CLAIM_AVG_ACC_ST_PRD_97.5' (0.0000)
# 2702. feature 'CLAIM_AVG_ACC_ST_PRD_24.75' (0.0000)
# 2703. feature 'POLICY_INTERMEDIARY_780' (0.0000)
# 2704. feature 'POLICY_INTERMEDIARY_278' (0.0000)
# 2705. feature 'CLAIM_AVG_ACC_ST_PRD_292' (0.0000)

# %%
# Построим альтернативную модель с помощью градиентного бустинга над деревьями с тем же количеством деревьев 
# Build alternative model with trees gradient boosting with the same number of trees

from sklearn import ensemble
gbt = ensemble.GradientBoostingClassifier(n_estimators=100, random_state=11)
gbt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=1,
#               min_samples_split=2, min_weight_fraction_leaf=0.0,
#               n_estimators=100, presort='auto', random_state=11,
#               subsample=1.0, verbose=0, warm_start=False)

# %%
# Рассчитаем различные метрики качества модели
# Calculate different quality metrics of gradient boosting model

print("precision:",metrics.precision_score(y_test, gbt.predict(X_test)))
print("recall:",metrics.recall_score(y_test, gbt.predict(X_test)))
print("roc_auc:",roc_auc_score(y_test, gbt.predict(X_test)))
print("gini:",2*roc_auc_score(y_test, gbt.predict(X_test))-1)
print ("accuracy:",accuracy_score(y_test, gbt.predict(X_test)))
# Out:
# precision: 0.7078700675822978
# recall: 0.9003812824956673
# roc_auc: 0.6348223192897258
# gini: 0.26964463857945153
# accuracy: 0.7034855821663831
